# %% [markdown]
# ### Prof. Pedram Jahangiry
#
# You need to make a copy to your own Google drive if you want to edit the original notebook! Start by opening this notebook on Colab 👇
#
# <a href="https://colab.research.google.com/github/PJalgotrader/Deep_Learning-USU/blob/main/Platforms%20and%20tools/PyCaret/PyCaret-RegressionDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
#
# ## 🔗 Links
#
# [![linkedin](https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=FF0000)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
#
# [![Twitter URL](https://img.shields.io/twitter/url/https/twitter.com/PedramJahangiry.svg?style=social&label=Follow%20%40PedramJahangiry)](https://twitter.com/PedramJahangiry)
#
#
# ---

# %% [markdown]
# # ⚠️ Important: How to install PyCaret (read this first)
#
# **We are using PyCaret 3.5.0, installed from the `pycaret-core` package.** The older `pycaret==3.3.2` release only supports Python 3.9 to 3.11 and is no longer updated, so `pip install pycaret` does not work on Google Colab or on any current Python. `pycaret-core` is the maintained continuation of PyCaret 3: same `import pycaret`, same functions, and it runs on Python 3.13.
#
# ### On Google Colab
# Run the install cell below **first, in a fresh runtime**, before importing PyCaret. It detects Colab and runs:
# ```
# pip install pycaret-core xgboost lightgbm catboost shap
# ```
# This installs the PyCaret core library plus the three boosting libraries used in this notebook and `shap`, which `interpret_model()` needs.
#
# No runtime restart is needed after the install. PyCaret checks which optional libraries exist the first time it is imported, so anything you install *after* importing it stays invisible (`Estimator ... Not Available`). If that happens, use Runtime ▸ Disconnect and delete runtime, then run the notebook from the top.
#
# After the install finishes, verify with the version cell below (you should see **3.5.0**).
#
# ### On your own machine (conda)
# The install cell does nothing outside Colab. Instead, create the course's PyCaret environment once, from the root of your cloned copy of this repo:
# ```
# conda env create -f environment.yml
# conda activate dl_pycaret
# python scripts/check_environment.py
# ```
# [`environment.yml`](https://github.com/PJalgotrader/Deep_Learning-USU/blob/main/environment.yml) uses **Python 3.13** (the same as Colab) and covers every PyCaret notebook in this course. The check script should end with "Your course environment is ready." Then open this notebook in JupyterLab or VS Code and pick the `dl_pycaret` environment as the kernel. Details and troubleshooting are in the [PyCaret setup guide](https://github.com/PJalgotrader/Deep_Learning-USU/blob/main/Platforms%20and%20tools/PyCaret/README.md). For a walkthrough of PyCaret itself, see my PyCaret playlist: https://www.youtube.com/playlist?list=PL2GWo47BFyUOqCAj_16yeNspfeM0nfA6q

# %% [markdown]
# Source:
# 1. https://py-caret.readthedocs.io/en/latest/tutorials.html (PyCaret tutorials)
# 2. https://py-caret.readthedocs.io/en/latest/api/regression.html (regression API reference)
# 3. https://pypi.org/project/pycaret-core/3.5.0/ (pycaret-core 3.5.0 on PyPI, the package we install in this notebook)
# 4. https://github.com/sktime/pycaret/releases (PyCaret release notes)

# %% [markdown]
# # How to do Regression with PyCaret
#
# PyCaret's Regression module (pycaret.regression) is a supervised machine learning module which is used for predicting continuous values / outcomes using various techniques and algorithms. Regression can be used for predicting values / outcomes such as sales, units sold, temperature or any number which is continuous.
#
# PyCaret's regression module has over 25 algorithms and 10 plots to analyze the performance of models. Be it hyper-parameter tuning, ensembling or advanced techniques like stacking, PyCaret's regression module has it all.
#
# In this notebook, we will explore:
#
#
# * **Getting Data**: How to import data from PyCaret dataset
# * **Normalization**: How to normalize and scale the dataset
# * **Transformation**: How to apply transformations that make the data linear and approximately normal
# * **Target Transformation**: How to apply transformations to the target variable
# * **Ignore Low Variance**: How to remove features with statistically insignificant variances to make the experiment more efficient
# * **Remove Multi-collinearity**: How to remove multi-collinearity from the dataset to boost performance of Linear algorithms
# * **Group Features**: How to extract statistical information from related features in the dataset
# * **Combine Rare Levels**: How to combine rare levels in categorical features
# * **Bin Numeric Variables**: How to bin numeric variables and transform numeric features into categorical ones using 'sturges' rule
# * **Setting up Environment**: How to setup an experiment in PyCaret and get started with building regression models
# * **Create Model**: How to create a model, perform cross validation and evaluate regression metrics
# * **Tune Model**: How to automatically tune the hyperparameters of a regression model
# * **Plot Model**: How to analyze model performance using various plots
# * **Finalize Model**: How to finalize the best model at the end of the experiment
# * **Predict Model**: How to make prediction on new / unseen data
# * **Model Ensembling and Stacking**: How to boost model performance using several ensembling techniques such as Bagging, Boosting, Soft/hard Voting and Generalized Stacking
# * **Save / Load Model**: How to save / load a model for future use
# * **Experiment Logging**: How to log experiments in PyCaret using MLFlow backend

# %% [markdown]
# # Installation

# %% [markdown]
# Follow the instructions at the top of this notebook: on Google Colab run the next cell; on your own machine use the `dl_pycaret` conda environment, where the next cell does nothing.

# %%
# Google Colab only: installs PyCaret 3.5.0 (pycaret-core) plus the libraries this notebook needs.
# On your own machine this cell does nothing (use the dl_pycaret conda environment, see the note above).
# shap is needed by interpret_model().
# Run it FIRST in a fresh runtime, before importing pycaret.
import sys
if "google.colab" in sys.modules:
    # !pip install -q pycaret-core xgboost lightgbm catboost shap

# %%
# let's double ckeck the Pycaret version: 
from pycaret.utils import version
version()
# Out:
# '3.5.0'

# %% [markdown]
# # Importing Dataset

# %%
from pycaret.datasets import get_data

#here is the list of all available datasets
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
dataset = get_data('bike')
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  cnt
# 0           1  0.24  0.2879  0.81        0.0   16
# 1           1  0.22  0.2727  0.80        0.0   40
# 2           1  0.22  0.2727  0.80        0.0   32
# 3           1  0.24  0.2879  0.75        0.0   13
# 4           1  0.24  0.2879  0.75        0.0    1

# %%
# dataset = get_data('bike', profile=True) # profile=True is going to do an automated EDA, you need to "pip install pycaret[analysis]" first.

# %%
# for the sake of time, lets work with a tiny subsample of the data, 
dataset = dataset.sample(1000)

# %%
data = dataset.sample(frac=0.9, random_state=123)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (900, 15)
# Unseen Data For Predictions: (100, 15)

# %%
data.shape
# Out:
# (900, 15)

# %%
data.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0    11390  4/24/2012       2   1     4  18        0        2           1
# 1    14121  8/16/2012       3   1     8  13        0        4           1
# 2     5756   9/2/2011       3   0     9   6        0        5           1
# 3     5711  8/31/2011       3   0     8   9        0        3           1
# 4    14595   9/5/2012       3   1     9   7        0        3           1
#
#    weathersit  temp   atemp   hum  windspeed  cnt
# 0           1  0.50  0.4848  0.18     0.0000  632
# 1           1  0.80  0.6970  0.31     0.2239  300
# 2           1  0.60  0.5606  0.83     0.1343   76
# 3           1  0.64  0.6061  0.69     0.0896  244
# 4           2  0.70  0.6667  0.79     0.2537  500

# %%
data.nunique()
# Out:
# instant       900
# dteday        528
# season          4
# yr              2
# mnth           12
# hr             24
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp           46
# atemp          55
# hum            77
# windspeed      24
# cnt           423
# dtype: int64

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
categoricals = ['season', 'yr', 'mnth', 'hr','holiday', 'weekday','workingday','weathersit' ]
numericals   = ['temp', 'atemp', 'hum', 'windspeed']
ignore       = ['instant','dteday']

# %% [markdown]
# ## Setting up Environment in PyCaret
#
# **setup()**:
#
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function. It takes two mandatory parameters: data and target. All the other parameters are optional.

# %%
from pycaret.regression import *

# %% [markdown]
# The latest version of PyCaret is Object oriented API. This means that the settings are linked with an object, you can run as many experiments as you want in the same notebook and compare them seamlessly not just across different modeling options but also different preprocessing settings.

# %% [markdown]
# ### ⚠️ A note on `data_split_shuffle=False`
#
# On Python 3.13 with pandas ≥ 2.2 (both Google Colab and the `dl_pycaret` conda environment) PyCaret 3.5.0 has a preprocessing bug: when it merges transformed columns back into the dataset, pandas now **sorts the rows by index**, but the target column keeps its old order. Rows of `X` and `y` end up mismatched and any experiment with `preprocess=True` produces garbage scores (negative R²). Experiments with `preprocess=False` are not affected, but we use the same split settings in both so they stay comparable.
#
# Our `data` is already shuffled (we built it with `.sample()` and reset the index), so PyCaret does not need to shuffle it again: `data_split_shuffle=False` keeps the row index in increasing order and the sort becomes a no-op. Do **not** set `fold_shuffle=True` on this stack for the same reason.

# %%
# experience1 = no preprocessing
exp1 = RegressionExperiment()
exp1.setup(data, ignore_features=ignore,  target='cnt', session_id=555, train_size=0.7, preprocess=False, categorical_features= categoricals, numeric_features=numericals,
           data_split_shuffle=False)   # see the note above (Colab / pandas >= 2.2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7bdf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bdf9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7bdf9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bdf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7bdf9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7bdf9_row0_col1" class="data row0 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7bdf9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7bdf9_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7bdf9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7bdf9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7bdf9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7bdf9_row3_col1" class="data row3 col1" >(900, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7bdf9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7bdf9_row4_col1" class="data row4 col1" >(900, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7bdf9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7bdf9_row5_col1" class="data row5 col1" >(630, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7bdf9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7bdf9_row6_col1" class="data row6 col1" >(270, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7bdf9_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_7bdf9_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7bdf9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7bdf9_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7bdf9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7bdf9_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_7bdf9_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# experiment 2, with preprocessing and more!!!
exp2 = RegressionExperiment()
exp2.setup(data, ignore_features=ignore, target='cnt', session_id=555, train_size=0.7, categorical_features= categoricals, numeric_features=numericals, numeric_imputation='mean', categorical_imputation='mode' ,
           preprocess=True, normalize=True , remove_outliers=True, ordinal_features=None,
           data_split_shuffle=False)   # see the note above (Colab / pandas >= 2.2)
# Out:
# <style type="text/css">
# #T_90469_row10_col1, #T_90469_row16_col1, #T_90469_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_90469">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90469_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_90469_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90469_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90469_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_90469_row0_col1" class="data row0 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90469_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_90469_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90469_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_90469_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90469_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_90469_row3_col1" class="data row3 col1" >(900, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90469_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_90469_row4_col1" class="data row4 col1" >(868, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90469_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_90469_row5_col1" class="data row5 col1" >(598, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90469_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_90469_row6_col1" class="data row6 col1" >(270, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90469_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_90469_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90469_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_90469_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90469_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_90469_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_90469_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_90469_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_90469_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_90469_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_90469_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_90469_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_90469_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_90469_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_90469_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_90469_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_90469_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_90469_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_90469_row16_col0" class="data row16 col0" >Remove outliers</td>
#       <td id="T_90469_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_90469_row17_col0" class="data row17 col0" >Outliers threshold</td>
#       <td id="T_90469_row17_col1" class="data row17 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_90469_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_90469_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_90469_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_90469_row19_col1" class="data row19 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_90469_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_90469_row20_col1" class="data row20 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_90469_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_90469_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_90469_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_90469_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_90469_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_90469_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_90469_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_90469_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_90469_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_90469_row25_col1" class="data row25 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_90469_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_90469_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_90469_row26_col1" class="data row26 col1" >da6e</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compare Models
#
# This function trains and evaluates performance of all estimators available in the model library using cross validation. The output of this function is a score grid with average cross validated scores. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function.

# %%
top3_exp1 = exp1.compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_20437 th {
#   text-align: left;
# }
# #T_20437_row0_col0, #T_20437_row0_col5, #T_20437_row0_col6, #T_20437_row1_col0, #T_20437_row1_col1, #T_20437_row1_col2, #T_20437_row1_col3, #T_20437_row1_col4, #T_20437_row1_col5, #T_20437_row1_col6, #T_20437_row2_col0, #T_20437_row2_col1, #T_20437_row2_col2, #T_20437_row2_col3, #T_20437_row2_col4, #T_20437_row2_col5, #T_20437_row2_col6, #T_20437_row3_col0, #T_20437_row3_col1, #T_20437_row3_col2, #T_20437_row3_col3, #T_20437_row3_col4, #T_20437_row3_col5, #T_20437_row3_col6, #T_20437_row4_col0, #T_20437_row4_col1, #T_20437_row4_col2, #T_20437_row4_col3, #T_20437_row4_col4, #T_20437_row4_col5, #T_20437_row4_col6, #T_20437_row5_col0, #T_20437_row5_col1, #T_20437_row5_col2, #T_20437_row5_col3, #T_20437_row5_col4, #T_20437_row6_col0, #T_20437_row6_col1, #T_20437_row6_col2, #T_20437_row6_col3, #T_20437_row6_col4, #T_20437_row6_col5, #T_20437_row6_col6, #T_20437_row7_col0, #T_20437_row7_col1, #T_20437_row7_col2, #T_20437_row7_col3, #T_20437_row7_col4, #T_20437_row7_col5, #T_20437_row7_col6, #T_20437_row8_col0, #T_20437_row8_col1, #T_20437_row8_col2, #T_20437_row8_col3, #T_20437_row8_col4, #T_20437_row8_col5, #T_20437_row8_col6, #T_20437_row9_col0, #T_20437_row9_col1, #T_20437_row9_col2, #T_20437_row9_col3, #T_20437_row9_col4, #T_20437_row9_col5, #T_20437_row9_col6, #T_20437_row10_col0, #T_20437_row10_col1, #T_20437_row10_col2, #T_20437_row10_col3, #T_20437_row10_col4, #T_20437_row10_col5, #T_20437_row10_col6, #T_20437_row11_col0, #T_20437_row11_col1, #T_20437_row11_col2, #T_20437_row11_col3, #T_20437_row11_col4, #T_20437_row11_col5, #T_20437_row11_col6, #T_20437_row12_col0, #T_20437_row12_col1, #T_20437_row12_col2, #T_20437_row12_col3, #T_20437_row12_col4, #T_20437_row12_col5, #T_20437_row12_col6, #T_20437_row13_col0, #T_20437_row13_col1, #T_20437_row13_col2, #T_20437_row13_col3, #T_20437_row13_col4, #T_20437_row13_col5, #T_20437_row13_col6, #T_20437_row14_col0, #T_20437_row14_col1, #T_20437_row14_col2, #T_20437_row14_col3, #T_20437_row14_col4, #T_20437_row14_col5, #T_20437_row14_col6, #T_20437_row15_col0, #T_20437_row15_col1, #T_20437_row15_col2, #T_20437_row15_col3, #T_20437_row15_col4, #T_20437_row15_col5, #T_20437_row15_col6, #T_20437_row16_col0, #T_20437_row16_col1, #T_20437_row16_col2, #T_20437_row16_col3, #T_20437_row16_col4, #T_20437_row16_col5, #T_20437_row16_col6, #T_20437_row17_col0, #T_20437_row17_col1, #T_20437_row17_col2, #T_20437_row17_col3, #T_20437_row17_col4, #T_20437_row17_col5, #T_20437_row17_col6, #T_20437_row18_col0, #T_20437_row18_col1, #T_20437_row18_col2, #T_20437_row18_col3, #T_20437_row18_col4, #T_20437_row18_col5, #T_20437_row18_col6, #T_20437_row19_col0, #T_20437_row19_col1, #T_20437_row19_col2, #T_20437_row19_col3, #T_20437_row19_col4, #T_20437_row19_col5, #T_20437_row19_col6 {
#   text-align: left;
# }
# #T_20437_row0_col1, #T_20437_row0_col2, #T_20437_row0_col3, #T_20437_row0_col4, #T_20437_row5_col5, #T_20437_row5_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_20437_row0_col7, #T_20437_row1_col7, #T_20437_row2_col7, #T_20437_row3_col7, #T_20437_row4_col7, #T_20437_row5_col7, #T_20437_row6_col7, #T_20437_row7_col7, #T_20437_row9_col7, #T_20437_row11_col7, #T_20437_row12_col7, #T_20437_row14_col7, #T_20437_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_20437_row8_col7, #T_20437_row10_col7, #T_20437_row13_col7, #T_20437_row15_col7, #T_20437_row17_col7, #T_20437_row18_col7, #T_20437_row19_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_20437">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20437_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_20437_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_20437_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_20437_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_20437_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_20437_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_20437_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_20437_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20437_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_20437_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_20437_row0_col1" class="data row0 col1" >43.3430</td>
#       <td id="T_20437_row0_col2" class="data row0 col2" >3867.7493</td>
#       <td id="T_20437_row0_col3" class="data row0 col3" >61.6680</td>
#       <td id="T_20437_row0_col4" class="data row0 col4" >0.8880</td>
#       <td id="T_20437_row0_col5" class="data row0 col5" >0.6146</td>
#       <td id="T_20437_row0_col6" class="data row0 col6" >0.7850</td>
#       <td id="T_20437_row0_col7" class="data row0 col7" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_20437_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_20437_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_20437_row1_col1" class="data row1 col1" >53.0142</td>
#       <td id="T_20437_row1_col2" class="data row1 col2" >5862.9816</td>
#       <td id="T_20437_row1_col3" class="data row1 col3" >75.6736</td>
#       <td id="T_20437_row1_col4" class="data row1 col4" >0.8312</td>
#       <td id="T_20437_row1_col5" class="data row1 col5" >0.6179</td>
#       <td id="T_20437_row1_col6" class="data row1 col6" >0.7523</td>
#       <td id="T_20437_row1_col7" class="data row1 col7" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_20437_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_20437_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_20437_row2_col1" class="data row2 col1" >54.9553</td>
#       <td id="T_20437_row2_col2" class="data row2 col2" >6146.3298</td>
#       <td id="T_20437_row2_col3" class="data row2 col3" >77.5211</td>
#       <td id="T_20437_row2_col4" class="data row2 col4" >0.8221</td>
#       <td id="T_20437_row2_col5" class="data row2 col5" >0.6038</td>
#       <td id="T_20437_row2_col6" class="data row2 col6" >0.7281</td>
#       <td id="T_20437_row2_col7" class="data row2 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_20437_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_20437_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_20437_row3_col1" class="data row3 col1" >57.3338</td>
#       <td id="T_20437_row3_col2" class="data row3 col2" >6602.0315</td>
#       <td id="T_20437_row3_col3" class="data row3 col3" >80.0643</td>
#       <td id="T_20437_row3_col4" class="data row3 col4" >0.8086</td>
#       <td id="T_20437_row3_col5" class="data row3 col5" >0.6370</td>
#       <td id="T_20437_row3_col6" class="data row3 col6" >0.9054</td>
#       <td id="T_20437_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_20437_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_20437_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_20437_row4_col1" class="data row4 col1" >61.2336</td>
#       <td id="T_20437_row4_col2" class="data row4 col2" >7551.6825</td>
#       <td id="T_20437_row4_col3" class="data row4 col3" >86.2617</td>
#       <td id="T_20437_row4_col4" class="data row4 col4" >0.7817</td>
#       <td id="T_20437_row4_col5" class="data row4 col5" >0.7210</td>
#       <td id="T_20437_row4_col6" class="data row4 col6" >1.0754</td>
#       <td id="T_20437_row4_col7" class="data row4 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_20437_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_20437_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_20437_row5_col1" class="data row5 col1" >62.8142</td>
#       <td id="T_20437_row5_col2" class="data row5 col2" >8682.7079</td>
#       <td id="T_2

# %%
top3_exp1
# Out:
# [CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False),
#  LGBMRegressor(n_jobs=-1, random_state=555),
#  XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=-1, num_parallel_tree=None, ...)]

# %%
top3_exp2 = exp2.compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_7ed06 th {
#   text-align: left;
# }
# #T_7ed06_row0_col0, #T_7ed06_row0_col5, #T_7ed06_row0_col6, #T_7ed06_row1_col0, #T_7ed06_row1_col1, #T_7ed06_row1_col2, #T_7ed06_row1_col3, #T_7ed06_row1_col4, #T_7ed06_row1_col5, #T_7ed06_row1_col6, #T_7ed06_row2_col0, #T_7ed06_row2_col1, #T_7ed06_row2_col2, #T_7ed06_row2_col3, #T_7ed06_row2_col4, #T_7ed06_row2_col5, #T_7ed06_row2_col6, #T_7ed06_row3_col0, #T_7ed06_row3_col1, #T_7ed06_row3_col2, #T_7ed06_row3_col3, #T_7ed06_row3_col4, #T_7ed06_row4_col0, #T_7ed06_row4_col1, #T_7ed06_row4_col2, #T_7ed06_row4_col3, #T_7ed06_row4_col4, #T_7ed06_row4_col5, #T_7ed06_row4_col6, #T_7ed06_row5_col0, #T_7ed06_row5_col1, #T_7ed06_row5_col2, #T_7ed06_row5_col3, #T_7ed06_row5_col4, #T_7ed06_row5_col5, #T_7ed06_row5_col6, #T_7ed06_row6_col0, #T_7ed06_row6_col1, #T_7ed06_row6_col2, #T_7ed06_row6_col3, #T_7ed06_row6_col4, #T_7ed06_row6_col5, #T_7ed06_row6_col6, #T_7ed06_row7_col0, #T_7ed06_row7_col1, #T_7ed06_row7_col2, #T_7ed06_row7_col3, #T_7ed06_row7_col4, #T_7ed06_row7_col5, #T_7ed06_row7_col6, #T_7ed06_row8_col0, #T_7ed06_row8_col1, #T_7ed06_row8_col2, #T_7ed06_row8_col3, #T_7ed06_row8_col4, #T_7ed06_row8_col5, #T_7ed06_row8_col6, #T_7ed06_row9_col0, #T_7ed06_row9_col1, #T_7ed06_row9_col2, #T_7ed06_row9_col3, #T_7ed06_row9_col4, #T_7ed06_row9_col5, #T_7ed06_row9_col6, #T_7ed06_row10_col0, #T_7ed06_row10_col1, #T_7ed06_row10_col2, #T_7ed06_row10_col3, #T_7ed06_row10_col4, #T_7ed06_row10_col5, #T_7ed06_row10_col6, #T_7ed06_row11_col0, #T_7ed06_row11_col1, #T_7ed06_row11_col2, #T_7ed06_row11_col3, #T_7ed06_row11_col4, #T_7ed06_row11_col5, #T_7ed06_row11_col6, #T_7ed06_row12_col0, #T_7ed06_row12_col1, #T_7ed06_row12_col2, #T_7ed06_row12_col3, #T_7ed06_row12_col4, #T_7ed06_row12_col5, #T_7ed06_row12_col6, #T_7ed06_row13_col0, #T_7ed06_row13_col1, #T_7ed06_row13_col2, #T_7ed06_row13_col3, #T_7ed06_row13_col4, #T_7ed06_row13_col5, #T_7ed06_row13_col6, #T_7ed06_row14_col0, #T_7ed06_row14_col1, #T_7ed06_row14_col2, #T_7ed06_row14_col3, #T_7ed06_row14_col4, #T_7ed06_row14_col5, #T_7ed06_row14_col6, #T_7ed06_row15_col0, #T_7ed06_row15_col1, #T_7ed06_row15_col2, #T_7ed06_row15_col3, #T_7ed06_row15_col4, #T_7ed06_row15_col5, #T_7ed06_row15_col6, #T_7ed06_row16_col0, #T_7ed06_row16_col1, #T_7ed06_row16_col2, #T_7ed06_row16_col3, #T_7ed06_row16_col4, #T_7ed06_row16_col5, #T_7ed06_row16_col6, #T_7ed06_row17_col0, #T_7ed06_row17_col1, #T_7ed06_row17_col2, #T_7ed06_row17_col3, #T_7ed06_row17_col4, #T_7ed06_row17_col5, #T_7ed06_row17_col6, #T_7ed06_row18_col0, #T_7ed06_row18_col1, #T_7ed06_row18_col2, #T_7ed06_row18_col3, #T_7ed06_row18_col4, #T_7ed06_row18_col5, #T_7ed06_row18_col6, #T_7ed06_row19_col0, #T_7ed06_row19_col1, #T_7ed06_row19_col2, #T_7ed06_row19_col3, #T_7ed06_row19_col4, #T_7ed06_row19_col5, #T_7ed06_row19_col6 {
#   text-align: left;
# }
# #T_7ed06_row0_col1, #T_7ed06_row0_col2, #T_7ed06_row0_col3, #T_7ed06_row0_col4, #T_7ed06_row3_col5, #T_7ed06_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7ed06_row0_col7, #T_7ed06_row1_col7, #T_7ed06_row2_col7, #T_7ed06_row3_col7, #T_7ed06_row4_col7, #T_7ed06_row5_col7, #T_7ed06_row6_col7, #T_7ed06_row7_col7, #T_7ed06_row8_col7, #T_7ed06_row9_col7, #T_7ed06_row10_col7, #T_7ed06_row11_col7, #T_7ed06_row12_col7, #T_7ed06_row13_col7, #T_7ed06_row15_col7, #T_7ed06_row16_col7, #T_7ed06_row17_col7, #T_7ed06_row18_col7, #T_7ed06_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7ed06_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7ed06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed06_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7ed06_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7ed06_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7ed06_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7ed06_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7ed06_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7ed06_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7ed06_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed06_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_7ed06_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_7ed06_row0_col1" class="data row0 col1" >57.0139</td>
#       <td id="T_7ed06_row0_col2" class="data row0 col2" >6126.3565</td>
#       <td id="T_7ed06_row0_col3" class="data row0 col3" >77.7576</td>
#       <td id="T_7ed06_row0_col4" class="data row0 col4" >0.8221</td>
#       <td id="T_7ed06_row0_col5" class="data row0 col5" >0.7803</td>
#       <td id="T_7ed06_row0_col6" class="data row0 col6" >1.4127</td>
#       <td id="T_7ed06_row0_col7" class="data row0 col7" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_7ed06_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_7ed06_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_7ed06_row1_col1" class="data row1 col1" >66.1026</td>
#       <td id="T_7ed06_row1_col2" class="data row1 col2" >8602.9630</td>
#       <td id="T_7ed06_row1_col3" class="data row1 col3" >91.8801</td>
#       <td id="T_7ed06_row1_col4" class="data row1 col4" >0.7495</td>
#       <td id="T_7ed06_row1_col5" class="data row1 col5" >0.8075</td>
#       <td id="T_7ed06_row1_col6" class="data row1 col6" >1.4432</td>
#       <td id="T_7ed06_row1_col7" class="data row1 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_7ed06_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_7ed06_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7ed06_row2_col1" class="data row2 col1" >70.6181</td>
#       <td id="T_7ed06_row2_col2" class="data row2 col2" >9403.6641</td>
#       <td id="T_7ed06_row2_col3" class="data row2 col3" >96.2317</td>
#       <td id="T_7ed06_row2_col4" class="data row2 col4" >0.7260</td>
#       <td id="T_7ed06_row2_col5" class="data row2 col5" >0.8418</td>
#       <td id="T_7ed06_row2_col6" class="data row2 col6" >1.5282</td>
#       <td id="T_7ed06_row2_col7" class="data row2 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_7ed06_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_7ed06_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_7ed06_row3_col1" class="data row3 col1" >69.4679</td>
#       <td id="T_7ed06_row3_col2" class="data row3 col2" >9389.3407</td>
#       <td id="T_7ed06_row3_col3" class="data row3 col3" >96.4357</td>
#       <td id="T_7ed06_row3_col4" class="data row3 col4" >0.7227</td>
#       <td id="T_7ed06_row3_col5" class="data row3 col5" >0.7320</td>
#       <td id="T_7ed06_row3_col6" class="data row3 col6" >1.1393</td>
#       <td id="T_7ed06_row3_col7" class="data row3 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_7ed06_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_7ed06_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7ed06_row4_col1" class="data row4 col1" >68.8837</td>
#       <td id="T_7ed06_row4_col2" class="data row4 col2" >9865.0877</td>
#       <td id="T_7ed06_row4_col3" class="data row4 col3" >97.9866</td>
#       <td id="T_7ed06_row4_col4" class="data row4 col4" >0.7180</td>
#       <td id="T_7ed06_row4_col5" class="data row4 col5" >0.8134</td>
#       <td id="T_7ed06_row4_col6" class="data row4 col6" >1.3999</td>
#       <td id="T_7ed06_row4_col7" class="data row4 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_7ed06_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_7ed06_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_7ed06_row5_col1" class="data row5 col1" >78.2556</td>
#       <td id="T_7ed06_row5_col2" class="data row5 col2" >10971.9019</td>
#       <td id="T_7ed06_ro

# %% [markdown]
# ## Create Model
#
# This function trains and evaluates the performance of a given estimator using cross validation. The output of this function is a score grid with CV scores by fold. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function. All the available models can be accessed using the models function.

# %%
xgboost = exp1.create_model('xgboost')
# Out:
# <style type="text/css">
# #T_6e8e4_row10_col0, #T_6e8e4_row10_col1, #T_6e8e4_row10_col2, #T_6e8e4_row10_col3, #T_6e8e4_row10_col4, #T_6e8e4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6e8e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e8e4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6e8e4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6e8e4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6e8e4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6e8e4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6e8e4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e8e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e8e4_row0_col0" class="data row0 col0" >60.2139</td>
#       <td id="T_6e8e4_row0_col1" class="data row0 col1" >6766.7129</td>
#       <td id="T_6e8e4_row0_col2" class="data row0 col2" >82.2600</td>
#       <td id="T_6e8e4_row0_col3" class="data row0 col3" >0.8027</td>
#       <td id="T_6e8e4_row0_col4" class="data row0 col4" >0.6134</td>
#       <td id="T_6e8e4_row0_col5" class="data row0 col5" >0.6000</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e8e4_row1_col0" class="data row1 col0" >49.4707</td>
#       <td id="T_6e8e4_row1_col1" class="data row1 col1" >3796.8044</td>
#       <td id="T_6e8e4_row1_col2" class="data row1 col2" >61.6182</td>
#       <td id="T_6e8e4_row1_col3" class="data row1 col3" >0.8875</td>
#       <td id="T_6e8e4_row1_col4" class="data row1 col4" >0.7120</td>
#       <td id="T_6e8e4_row1_col5" class="data row1 col5" >0.9281</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e8e4_row2_col0" class="data row2 col0" >46.9345</td>
#       <td id="T_6e8e4_row2_col1" class="data row2 col1" >4240.5688</td>
#       <td id="T_6e8e4_row2_col2" class="data row2 col2" >65.1197</td>
#       <td id="T_6e8e4_row2_col3" class="data row2 col3" >0.8927</td>
#       <td id="T_6e8e4_row2_col4" class="data row2 col4" >0.5473</td>
#       <td id="T_6e8e4_row2_col5" class="data row2 col5" >0.5040</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e8e4_row3_col0" class="data row3 col0" >64.8810</td>
#       <td id="T_6e8e4_row3_col1" class="data row3 col1" >8308.1787</td>
#       <td id="T_6e8e4_row3_col2" class="data row3 col2" >91.1492</td>
#       <td id="T_6e8e4_row3_col3" class="data row3 col3" >0.8418</td>
#       <td id="T_6e8e4_row3_col4" class="data row3 col4" >0.4728</td>
#       <td id="T_6e8e4_row3_col5" class="data row3 col5" >0.5030</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e8e4_row4_col0" class="data row4 col0" >58.0069</td>
#       <td id="T_6e8e4_row4_col1" class="data row4 col1" >6719.9502</td>
#       <td id="T_6e8e4_row4_col2" class="data row4 col2" >81.9753</td>
#       <td id="T_6e8e4_row4_col3" class="data row4 col3" >0.8116</td>
#       <td id="T_6e8e4_row4_col4" class="data row4 col4" >0.6108</td>
#       <td id="T_6e8e4_row4_col5" class="data row4 col5" >1.0076</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e8e4_row5_col0" class="data row5 col0" >45.6802</td>
#       <td id="T_6e8e4_row5_col1" class="data row5 col1" >4838.3247</td>
#       <td id="T_6e8e4_row5_col2" class="data row5 col2" >69.5581</td>
#       <td id="T_6e8e4_row5_col3" class="data row5 col3" >0.8243</td>
#       <td id="T_6e8e4_row5_col4" class="data row5 col4" >0.6518</td>
#       <td id="T_6e8e4_row5_col5" class="data row5 col5" >0.6953</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e8e4_row6_col0" class="data row6 col0" >67.8975</td>
#       <td id="T_6e8e4_row6_col1" class="data row6 col1" >10454.5977</td>
#       <td id="T_6e8e4_row6_col2" class="data row6 col2" >102.2477</td>
#       <td id="T_6e8e4_row6_col3" class="data row6 col3" >0.7542</td>
#       <td id="T_6e8e4_row6_col4" class="data row6 col4" >0.6080</td>
#       <td id="T_6e8e4_row6_col5" class="data row6 col5" >0.7638</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e8e4_row7_col0" class="data row7 col0" >49.0900</td>
#       <td id="T_6e8e4_row7_col1" class="data row7 col1" >5928.1665</td>
#       <td id="T_6e8e4_row7_col2" class="data row7 col2" >76.9946</td>
#       <td id="T_6e8e4_row7_col3" class="data row7 col3" >0.8296</td>
#       <td id="T_6e8e4_row7_col4" class="data row7 col4" >0.5125</td>
#       <td id="T_6e8e4_row7_col5" class="data row7 col5" >0.5153</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e8e4_row8_col0" class="data row8 col0" >56.5052</td>
#       <td id="T_6e8e4_row8_col1" class="data row8 col1" >5271.0254</td>
#       <td id="T_6e8e4_row8_col2" class="data row8 col2" >72.6018</td>
#       <td id="T_6e8e4_row8_col3" class="data row8 col3" >0.7390</td>
#       <td id="T_6e8e4_row8_col4" class="data row8 col4" >0.7446</td>
#       <td id="T_6e8e4_row8_col5" class="data row8 col5" >1.1929</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e8e4_row9_col0" class="data row9 col0" >50.8728</td>
#       <td id="T_6e8e4_row9_col1" class="data row9 col1" >5138.9683</td>
#       <td id="T_6e8e4_row9_col2" class="data row9 col2" >71.6866</td>
#       <td id="T_6e8e4_row9_col3" class="data row9 col3" >0.8373</td>
#       <td id="T_6e8e4_row9_col4" class="data row9 col4" >0.5645</td>
#       <td id="T_6e8e4_row9_col5" class="data row9 col5" >0.5706</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6e8e4_row10_col0" class="data row10 col0" >54.9553</td>
#       <td id="T_6e8e4_row10_col1" class="data row10 col1" >6146.3298</td>
#       <td id="T_6e8e4_row10_col2" class="data row10 col2" >77.5211</td>
#       <td id="T_6e8e4_row10_col3" class="data row10 col3" >0.8221</td>
#       <td id="T_6e8e4_row10_col4" class="data row10 col4" >0.6038</td>
#       <td id="T_6e8e4_row10_col5" class="data row10 col5" >0.7281</td>
#     </tr>
#     <tr>
#       <th id="T_6e8e4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6e8e4_row11_col0" class="data row11 col0" >7.3273</td>
#       <td id="T_6e8e4_row11_col1" class="data row11 col1" >1914.1651</td>
#       <td id="T_6e8e4_row11_col2" class="data row11 col2" >11.6964</td>
#       <td id="T_6e8e4_row11_col3" class="data row11 col3" >0.0468</td>
#       <td id="T_6e8e4_row11_col4" class="data row11 col4" >0.0801</td>
#       <td id="T_6e8e4_row11_col5" class="data row11 col5" >0.2289</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tune model
#
# This function tunes the hyperparameters of a given estimator. The output of this function is a score grid with CV scores by fold of the best selected model based on optimize parameter. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function.

# %%
tune_xgboost = exp1.tune_model(xgboost)
# Out:
# <style type="text/css">
# #T_30cf9_row10_col0, #T_30cf9_row10_col1, #T_30cf9_row10_col2, #T_30cf9_row10_col3, #T_30cf9_row10_col4, #T_30cf9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_30cf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30cf9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_30cf9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_30cf9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_30cf9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_30cf9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_30cf9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30cf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30cf9_row0_col0" class="data row0 col0" >57.7093</td>
#       <td id="T_30cf9_row0_col1" class="data row0 col1" >6264.3423</td>
#       <td id="T_30cf9_row0_col2" class="data row0 col2" >79.1476</td>
#       <td id="T_30cf9_row0_col3" class="data row0 col3" >0.8173</td>
#       <td id="T_30cf9_row0_col4" class="data row0 col4" >0.5782</td>
#       <td id="T_30cf9_row0_col5" class="data row0 col5" >0.8457</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30cf9_row1_col0" class="data row1 col0" >46.1732</td>
#       <td id="T_30cf9_row1_col1" class="data row1 col1" >3947.6365</td>
#       <td id="T_30cf9_row1_col2" class="data row1 col2" >62.8302</td>
#       <td id="T_30cf9_row1_col3" class="data row1 col3" >0.8830</td>
#       <td id="T_30cf9_row1_col4" class="data row1 col4" >0.7174</td>
#       <td id="T_30cf9_row1_col5" class="data row1 col5" >0.9147</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30cf9_row2_col0" class="data row2 col0" >42.5686</td>
#       <td id="T_30cf9_row2_col1" class="data row2 col1" >3403.8313</td>
#       <td id="T_30cf9_row2_col2" class="data row2 col2" >58.3424</td>
#       <td id="T_30cf9_row2_col3" class="data row2 col3" >0.9139</td>
#       <td id="T_30cf9_row2_col4" class="data row2 col4" >0.5847</td>
#       <td id="T_30cf9_row2_col5" class="data row2 col5" >0.7981</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30cf9_row3_col0" class="data row3 col0" >57.3572</td>
#       <td id="T_30cf9_row3_col1" class="data row3 col1" >5977.6538</td>
#       <td id="T_30cf9_row3_col2" class="data row3 col2" >77.3153</td>
#       <td id="T_30cf9_row3_col3" class="data row3 col3" >0.8861</td>
#       <td id="T_30cf9_row3_col4" class="data row3 col4" >0.5010</td>
#       <td id="T_30cf9_row3_col5" class="data row3 col5" >0.5118</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30cf9_row4_col0" class="data row4 col0" >48.9163</td>
#       <td id="T_30cf9_row4_col1" class="data row4 col1" >4445.7256</td>
#       <td id="T_30cf9_row4_col2" class="data row4 col2" >66.6763</td>
#       <td id="T_30cf9_row4_col3" class="data row4 col3" >0.8754</td>
#       <td id="T_30cf9_row4_col4" class="data row4 col4" >0.6362</td>
#       <td id="T_30cf9_row4_col5" class="data row4 col5" >1.0488</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_30cf9_row5_col0" class="data row5 col0" >41.5291</td>
#       <td id="T_30cf9_row5_col1" class="data row5 col1" >3537.5037</td>
#       <td id="T_30cf9_row5_col2" class="data row5 col2" >59.4769</td>
#       <td id="T_30cf9_row5_col3" class="data row5 col3" >0.8715</td>
#       <td id="T_30cf9_row5_col4" class="data row5 col4" >0.7718</td>
#       <td id="T_30cf9_row5_col5" class="data row5 col5" >0.9954</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_30cf9_row6_col0" class="data row6 col0" >60.5404</td>
#       <td id="T_30cf9_row6_col1" class="data row6 col1" >7547.4849</td>
#       <td id="T_30cf9_row6_col2" class="data row6 col2" >86.8763</td>
#       <td id="T_30cf9_row6_col3" class="data row6 col3" >0.8226</td>
#       <td id="T_30cf9_row6_col4" class="data row6 col4" >0.6127</td>
#       <td id="T_30cf9_row6_col5" class="data row6 col5" >0.7278</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_30cf9_row7_col0" class="data row7 col0" >53.5661</td>
#       <td id="T_30cf9_row7_col1" class="data row7 col1" >6503.1050</td>
#       <td id="T_30cf9_row7_col2" class="data row7 col2" >80.6418</td>
#       <td id="T_30cf9_row7_col3" class="data row7 col3" >0.8131</td>
#       <td id="T_30cf9_row7_col4" class="data row7 col4" >0.6198</td>
#       <td id="T_30cf9_row7_col5" class="data row7 col5" >0.8012</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_30cf9_row8_col0" class="data row8 col0" >43.7117</td>
#       <td id="T_30cf9_row8_col1" class="data row8 col1" >3548.4915</td>
#       <td id="T_30cf9_row8_col2" class="data row8 col2" >59.5692</td>
#       <td id="T_30cf9_row8_col3" class="data row8 col3" >0.8243</td>
#       <td id="T_30cf9_row8_col4" class="data row8 col4" >0.6340</td>
#       <td id="T_30cf9_row8_col5" class="data row8 col5" >0.9494</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_30cf9_row9_col0" class="data row9 col0" >47.2593</td>
#       <td id="T_30cf9_row9_col1" class="data row9 col1" >4301.8062</td>
#       <td id="T_30cf9_row9_col2" class="data row9 col2" >65.5882</td>
#       <td id="T_30cf9_row9_col3" class="data row9 col3" >0.8638</td>
#       <td id="T_30cf9_row9_col4" class="data row9 col4" >0.5422</td>
#       <td id="T_30cf9_row9_col5" class="data row9 col5" >0.7412</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_30cf9_row10_col0" class="data row10 col0" >49.9331</td>
#       <td id="T_30cf9_row10_col1" class="data row10 col1" >4947.7581</td>
#       <td id="T_30cf9_row10_col2" class="data row10 col2" >69.6464</td>
#       <td id="T_30cf9_row10_col3" class="data row10 col3" >0.8571</td>
#       <td id="T_30cf9_row10_col4" class="data row10 col4" >0.6198</td>
#       <td id="T_30cf9_row10_col5" class="data row10 col5" >0.8334</td>
#     </tr>
#     <tr>
#       <th id="T_30cf9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_30cf9_row11_col0" class="data row11 col0" >6.5360</td>
#       <td id="T_30cf9_row11_col1" class="data row11 col1" >1413.2152</td>
#       <td id="T_30cf9_row11_col2" class="data row11 col2" >9.8557</td>
#       <td id="T_30cf9_row11_col3" class="data row11 col3" >0.0333</td>
#       <td id="T_30cf9_row11_col4" class="data row11 col4" >0.0750</td>
#       <td id="T_30cf9_row11_col5" class="data row11 col5" >0.1477</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
xgboost
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
tune_xgboost
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cpu', early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=np.int64(6),
#              max_leaves=None, min_child_weight=2, missing=nan,
#              monotone_constraints=None, multi_strategy=None,
#              n_estimators=np.int64(240), n_jobs=-1, num_parallel_tree=None, ...)

# %% [markdown]
# ## Plot Model
#
# This function analyzes the performance of a trained model on holdout set. It may require re-training the model in certain cases

# %%
exp1.plot_model(tune_xgboost)

# %%
exp1.plot_model(tune_xgboost, plot = 'error')

# %%
exp1.plot_model(tune_xgboost, plot = 'feature')

# %%
exp1.plot_model(tune_xgboost, plot = 'parameter')
# Out:
#                                Parameters
# objective                reg:squarederror
# base_score                           None
# booster                            gbtree
# callbacks                            None
# colsample_bylevel                    None
# colsample_bynode                     None
# colsample_bytree                      0.7
# device                                cpu
# early_stopping_rounds                None
# enable_categorical                   True
# eval_metric                          None
# feature_types                        None
# feature_weights                      None
# gamma                                None
# grow_policy                          None
# importance_type                      None
# interaction_constraints              None
# learning_rate                         0.1
# max_bin                              None
# max_cat_threshold                    None
# max_cat_to_onehot                    None
# max_delta_step                       None
# max_depth                               6
# max_leaves                           None
# min_child_weight                        2
# missing                               nan
# monotone_constraints                 None
# multi_strategy                       None
# n_estimators                          240
# n_jobs                                 -1
# num_parallel_tree                    None
# random_state                          555
# reg_alpha                           0.001
# reg_lambda                              4
# sampling_method                      None
# scale_pos_weight                     16.7
# subsample                             0.7
# tree_method                          auto
# validate_parameters                  None
# verbosity                               0

# %%
exp1.plot_model(tune_xgboost, plot = 'learning')

# %% [markdown]
# the model has high variance, increasing sample size will help.

# %%
exp1.plot_model(tune_xgboost, plot = 'vc')

# %% [markdown]
# As you can see, the model is overfitting with max_depth = 9.

# %%
exp1.plot_model(tune_xgboost, plot = 'manifold')

# %% [markdown]
# ## Evaluate model
#
# This function displays a user interface for analyzing performance of a trained model. It calls the plot_model function internally.
#
# *I don't recommend using this evaluate model functionality! very slow plus bugs! do separate plots instead.*

# %%
lr = exp1.create_model('lr', fold=5)
# Out:
# <style type="text/css">
# #T_d6452_row5_col0, #T_d6452_row5_col1, #T_d6452_row5_col2, #T_d6452_row5_col3, #T_d6452_row5_col4, #T_d6452_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d6452">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6452_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d6452_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d6452_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d6452_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d6452_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d6452_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6452_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6452_row0_col0" class="data row0 col0" >106.6966</td>
#       <td id="T_d6452_row0_col1" class="data row0 col1" >18395.6934</td>
#       <td id="T_d6452_row0_col2" class="data row0 col2" >135.6307</td>
#       <td id="T_d6452_row0_col3" class="data row0 col3" >0.4698</td>
#       <td id="T_d6452_row0_col4" class="data row0 col4" >1.2599</td>
#       <td id="T_d6452_row0_col5" class="data row0 col5" >3.8291</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6452_row1_col0" class="data row1 col0" >131.9147</td>
#       <td id="T_d6452_row1_col1" class="data row1 col1" >28481.7598</td>
#       <td id="T_d6452_row1_col2" class="data row1 col2" >168.7654</td>
#       <td id="T_d6452_row1_col3" class="data row1 col3" >0.3815</td>
#       <td id="T_d6452_row1_col4" class="data row1 col4" >1.1847</td>
#       <td id="T_d6452_row1_col5" class="data row1 col5" >2.4230</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6452_row2_col0" class="data row2 col0" >106.0007</td>
#       <td id="T_d6452_row2_col1" class="data row2 col1" >20532.6465</td>
#       <td id="T_d6452_row2_col2" class="data row2 col2" >143.2922</td>
#       <td id="T_d6452_row2_col3" class="data row2 col3" >0.3537</td>
#       <td id="T_d6452_row2_col4" class="data row2 col4" >1.2687</td>
#       <td id="T_d6452_row2_col5" class="data row2 col5" >3.8517</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6452_row3_col0" class="data row3 col0" >99.7465</td>
#       <td id="T_d6452_row3_col1" class="data row3 col1" >20059.5215</td>
#       <td id="T_d6452_row3_col2" class="data row3 col2" >141.6316</td>
#       <td id="T_d6452_row3_col3" class="data row3 col3" >0.4840</td>
#       <td id="T_d6452_row3_col4" class="data row3 col4" >1.0300</td>
#       <td id="T_d6452_row3_col5" class="data row3 col5" >2.1948</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6452_row4_col0" class="data row4 col0" >95.7868</td>
#       <td id="T_d6452_row4_col1" class="data row4 col1" >14807.2842</td>
#       <td id="T_d6452_row4_col2" class="data row4 col2" >121.6852</td>
#       <td id="T_d6452_row4_col3" class="data row4 col3" >0.4304</td>
#       <td id="T_d6452_row4_col4" class="data row4 col4" >1.2292</td>
#       <td id="T_d6452_row4_col5" class="data row4 col5" >4.0011</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d6452_row5_col0" class="data row5 col0" >108.0291</td>
#       <td id="T_d6452_row5_col1" class="data row5 col1" >20455.3811</td>
#       <td id="T_d6452_row5_col2" class="data row5 col2" >142.2010</td>
#       <td id="T_d6452_row5_col3" class="data row5 col3" >0.4239</td>
#       <td id="T_d6452_row5_col4" class="data row5 col4" >1.1945</td>
#       <td id="T_d6452_row5_col5" class="data row5 col5" >3.2599</td>
#     </tr>
#     <tr>
#       <th id="T_d6452_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d6452_row6_col0" class="data row6 col0" >12.6086</td>
#       <td id="T_d6452_row6_col1" class="data row6 col1" >4488.4015</td>
#       <td id="T_d6452_row6_col2" class="data row6 col2" >15.3052</td>
#       <td id="T_d6452_row6_col3" class="data row6 col3" >0.0500</td>
#       <td id="T_d6452_row6_col4" class="data row6 col4" >0.0873</td>
#       <td id="T_d6452_row6_col5" class="data row6 col5" >0.7821</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp1.evaluate_model(lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Interpret model
#
# This function analyzes the predictions generated from a trained model. Most plots in this function are implemented based on the SHAP (SHapley Additive exPlanations). For more info on this, please see https://shap.readthedocs.io/en/latest/

# %%
exp1.interpret_model(tune_xgboost)

# %% [markdown]
# ## Ensemble a Model
# Ensembling is a common machine learning technique used to improve the performance of models (mostly tree based). There are various techniques for ensembling that we will cover in this section. These include Bagging and Boosting

# %%
# lets create a simple decision tree model that we will use for ensembling 
dt = exp1.create_model('dt')
# Out:
# <style type="text/css">
# #T_3334d_row10_col0, #T_3334d_row10_col1, #T_3334d_row10_col2, #T_3334d_row10_col3, #T_3334d_row10_col4, #T_3334d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3334d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3334d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3334d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3334d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3334d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3334d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3334d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3334d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3334d_row0_col0" class="data row0 col0" >95.6825</td>
#       <td id="T_3334d_row0_col1" class="data row0 col1" >18570.5397</td>
#       <td id="T_3334d_row0_col2" class="data row0 col2" >136.2738</td>
#       <td id="T_3334d_row0_col3" class="data row0 col3" >0.4585</td>
#       <td id="T_3334d_row0_col4" class="data row0 col4" >0.6993</td>
#       <td id="T_3334d_row0_col5" class="data row0 col5" >0.7363</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3334d_row1_col0" class="data row1 col0" >82.5079</td>
#       <td id="T_3334d_row1_col1" class="data row1 col1" >19155.0476</td>
#       <td id="T_3334d_row1_col2" class="data row1 col2" >138.4018</td>
#       <td id="T_3334d_row1_col3" class="data row1 col3" >0.4322</td>
#       <td id="T_3334d_row1_col4" class="data row1 col4" >0.7150</td>
#       <td id="T_3334d_row1_col5" class="data row1 col5" >0.7655</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3334d_row2_col0" class="data row2 col0" >68.5079</td>
#       <td id="T_3334d_row2_col1" class="data row2 col1" >16305.3016</td>
#       <td id="T_3334d_row2_col2" class="data row2 col2" >127.6922</td>
#       <td id="T_3334d_row2_col3" class="data row2 col3" >0.5874</td>
#       <td id="T_3334d_row2_col4" class="data row2 col4" >0.6945</td>
#       <td id="T_3334d_row2_col5" class="data row2 col5" >0.6483</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3334d_row3_col0" class="data row3 col0" >98.0317</td>
#       <td id="T_3334d_row3_col1" class="data row3 col1" >22194.4127</td>
#       <td id="T_3334d_row3_col2" class="data row3 col2" >148.9779</td>
#       <td id="T_3334d_row3_col3" class="data row3 col3" >0.5773</td>
#       <td id="T_3334d_row3_col4" class="data row3 col4" >0.6132</td>
#       <td id="T_3334d_row3_col5" class="data row3 col5" >0.5968</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3334d_row4_col0" class="data row4 col0" >90.6825</td>
#       <td id="T_3334d_row4_col1" class="data row4 col1" >17007.0000</td>
#       <td id="T_3334d_row4_col2" class="data row4 col2" >130.4109</td>
#       <td id="T_3334d_row4_col3" class="data row4 col3" >0.5233</td>
#       <td id="T_3334d_row4_col4" class="data row4 col4" >0.7791</td>
#       <td id="T_3334d_row4_col5" class="data row4 col5" >0.9958</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3334d_row5_col0" class="data row5 col0" >58.3333</td>
#       <td id="T_3334d_row5_col1" class="data row5 col1" >9506.1746</td>
#       <td id="T_3334d_row5_col2" class="data row5 col2" >97.4996</td>
#       <td id="T_3334d_row5_col3" class="data row5 col3" >0.6548</td>
#       <td id="T_3334d_row5_col4" class="data row5 col4" >0.6266</td>
#       <td id="T_3334d_row5_col5" class="data row5 col5" >0.6475</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3334d_row6_col0" class="data row6 col0" >101.3651</td>
#       <td id="T_3334d_row6_col1" class="data row6 col1" >24866.8571</td>
#       <td id="T_3334d_row6_col2" class="data row6 col2" >157.6923</td>
#       <td id="T_3334d_row6_col3" class="data row6 col3" >0.4155</td>
#       <td id="T_3334d_row6_col4" class="data row6 col4" >0.6654</td>
#       <td id="T_3334d_row6_col5" class="data row6 col5" >0.8387</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3334d_row7_col0" class="data row7 col0" >79.1429</td>
#       <td id="T_3334d_row7_col1" class="data row7 col1" >17477.2381</td>
#       <td id="T_3334d_row7_col2" class="data row7 col2" >132.2015</td>
#       <td id="T_3334d_row7_col3" class="data row7 col3" >0.4976</td>
#       <td id="T_3334d_row7_col4" class="data row7 col4" >0.5955</td>
#       <td id="T_3334d_row7_col5" class="data row7 col5" >0.5681</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3334d_row8_col0" class="data row8 col0" >79.2698</td>
#       <td id="T_3334d_row8_col1" class="data row8 col1" >15270.1905</td>
#       <td id="T_3334d_row8_col2" class="data row8 col2" >123.5726</td>
#       <td id="T_3334d_row8_col3" class="data row8 col3" >0.2440</td>
#       <td id="T_3334d_row8_col4" class="data row8 col4" >0.7539</td>
#       <td id="T_3334d_row8_col5" class="data row8 col5" >1.0357</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3334d_row9_col0" class="data row9 col0" >80.0952</td>
#       <td id="T_3334d_row9_col1" class="data row9 col1" >12452.0317</td>
#       <td id="T_3334d_row9_col2" class="data row9 col2" >111.5887</td>
#       <td id="T_3334d_row9_col3" class="data row9 col3" >0.6057</td>
#       <td id="T_3334d_row9_col4" class="data row9 col4" >0.7225</td>
#       <td id="T_3334d_row9_col5" class="data row9 col5" >0.8460</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3334d_row10_col0" class="data row10 col0" >83.3619</td>
#       <td id="T_3334d_row10_col1" class="data row10 col1" >17280.4794</td>
#       <td id="T_3334d_row10_col2" class="data row10 col2" >130.4311</td>
#       <td id="T_3334d_row10_col3" class="data row10 col3" >0.4996</td>
#       <td id="T_3334d_row10_col4" class="data row10 col4" >0.6865</td>
#       <td id="T_3334d_row10_col5" class="data row10 col5" >0.7679</td>
#     </tr>
#     <tr>
#       <th id="T_3334d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3334d_row11_col0" class="data row11 col0" >12.7974</td>
#       <td id="T_3334d_row11_col1" class="data row11 col1" >4192.1067</td>
#       <td id="T_3334d_row11_col2" class="data row11 col2" >16.3769</td>
#       <td id="T_3334d_row11_col3" class="data row11 col3" >0.1133</td>
#       <td id="T_3334d_row11_col4" class="data row11 col4" >0.0576</td>
#       <td id="T_3334d_row11_col5" class="data row11 col5" >0.1529</td>
#     </tr>
#   </tbody>
# </table>

# %%
bagged_dt = exp1.ensemble_model(dt)
# Out:
# <style type="text/css">
# #T_914b4_row10_col0, #T_914b4_row10_col1, #T_914b4_row10_col2, #T_914b4_row10_col3, #T_914b4_row10_col4, #T_914b4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_914b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_914b4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_914b4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_914b4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_914b4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_914b4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_914b4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_914b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_914b4_row0_col0" class="data row0 col0" >68.6032</td>
#       <td id="T_914b4_row0_col1" class="data row0 col1" >10369.8219</td>
#       <td id="T_914b4_row0_col2" class="data row0 col2" >101.8323</td>
#       <td id="T_914b4_row0_col3" class="data row0 col3" >0.6976</td>
#       <td id="T_914b4_row0_col4" class="data row0 col4" >0.5340</td>
#       <td id="T_914b4_row0_col5" class="data row0 col5" >0.6077</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_914b4_row1_col0" class="data row1 col0" >62.9968</td>
#       <td id="T_914b4_row1_col1" class="data row1 col1" >7938.8765</td>
#       <td id="T_914b4_row1_col2" class="data row1 col2" >89.1004</td>
#       <td id="T_914b4_row1_col3" class="data row1 col3" >0.7647</td>
#       <td id="T_914b4_row1_col4" class="data row1 col4" >0.6014</td>
#       <td id="T_914b4_row1_col5" class="data row1 col5" >0.7254</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_914b4_row2_col0" class="data row2 col0" >63.5254</td>
#       <td id="T_914b4_row2_col1" class="data row2 col1" >8880.5890</td>
#       <td id="T_914b4_row2_col2" class="data row2 col2" >94.2369</td>
#       <td id="T_914b4_row2_col3" class="data row2 col3" >0.7753</td>
#       <td id="T_914b4_row2_col4" class="data row2 col4" >0.4391</td>
#       <td id="T_914b4_row2_col5" class="data row2 col5" >0.4229</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_914b4_row3_col0" class="data row3 col0" >81.7540</td>
#       <td id="T_914b4_row3_col1" class="data row3 col1" >14391.2916</td>
#       <td id="T_914b4_row3_col2" class="data row3 col2" >119.9637</td>
#       <td id="T_914b4_row3_col3" class="data row3 col3" >0.7259</td>
#       <td id="T_914b4_row3_col4" class="data row3 col4" >0.4946</td>
#       <td id="T_914b4_row3_col5" class="data row3 col5" >0.5013</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_914b4_row4_col0" class="data row4 col0" >73.3810</td>
#       <td id="T_914b4_row4_col1" class="data row4 col1" >10370.6025</td>
#       <td id="T_914b4_row4_col2" class="data row4 col2" >101.8362</td>
#       <td id="T_914b4_row4_col3" class="data row4 col3" >0.7093</td>
#       <td id="T_914b4_row4_col4" class="data row4 col4" >0.7168</td>
#       <td id="T_914b4_row4_col5" class="data row4 col5" >0.9962</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_914b4_row5_col0" class="data row5 col0" >55.8270</td>
#       <td id="T_914b4_row5_col1" class="data row5 col1" >8322.6494</td>
#       <td id="T_914b4_row5_col2" class="data row5 col2" >91.2286</td>
#       <td id="T_914b4_row5_col3" class="data row5 col3" >0.6978</td>
#       <td id="T_914b4_row5_col4" class="data row5 col4" >0.6125</td>
#       <td id="T_914b4_row5_col5" class="data row5 col5" >0.7365</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_914b4_row6_col0" class="data row6 col0" >80.8333</td>
#       <td id="T_914b4_row6_col1" class="data row6 col1" >15311.9532</td>
#       <td id="T_914b4_row6_col2" class="data row6 col2" >123.7415</td>
#       <td id="T_914b4_row6_col3" class="data row6 col3" >0.6401</td>
#       <td id="T_914b4_row6_col4" class="data row6 col4" >0.6022</td>
#       <td id="T_914b4_row6_col5" class="data row6 col5" >0.6952</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_914b4_row7_col0" class="data row7 col0" >57.2302</td>
#       <td id="T_914b4_row7_col1" class="data row7 col1" >9926.8551</td>
#       <td id="T_914b4_row7_col2" class="data row7 col2" >99.6336</td>
#       <td id="T_914b4_row7_col3" class="data row7 col3" >0.7146</td>
#       <td id="T_914b4_row7_col4" class="data row7 col4" >0.5200</td>
#       <td id="T_914b4_row7_col5" class="data row7 col5" >0.5573</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_914b4_row8_col0" class="data row8 col0" >59.4111</td>
#       <td id="T_914b4_row8_col1" class="data row8 col1" >6376.1983</td>
#       <td id="T_914b4_row8_col2" class="data row8 col2" >79.8511</td>
#       <td id="T_914b4_row8_col3" class="data row8 col3" >0.6843</td>
#       <td id="T_914b4_row8_col4" class="data row8 col4" >0.6307</td>
#       <td id="T_914b4_row8_col5" class="data row8 col5" >0.8386</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_914b4_row9_col0" class="data row9 col0" >53.2984</td>
#       <td id="T_914b4_row9_col1" class="data row9 col1" >5601.2413</td>
#       <td id="T_914b4_row9_col2" class="data row9 col2" >74.8414</td>
#       <td id="T_914b4_row9_col3" class="data row9 col3" >0.8226</td>
#       <td id="T_914b4_row9_col4" class="data row9 col4" >0.6385</td>
#       <td id="T_914b4_row9_col5" class="data row9 col5" >0.9079</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_914b4_row10_col0" class="data row10 col0" >65.6860</td>
#       <td id="T_914b4_row10_col1" class="data row10 col1" >9749.0079</td>
#       <td id="T_914b4_row10_col2" class="data row10 col2" >97.6266</td>
#       <td id="T_914b4_row10_col3" class="data row10 col3" >0.7232</td>
#       <td id="T_914b4_row10_col4" class="data row10 col4" >0.5790</td>
#       <td id="T_914b4_row10_col5" class="data row10 col5" >0.6989</td>
#     </tr>
#     <tr>
#       <th id="T_914b4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_914b4_row11_col0" class="data row11 col0" >9.6373</td>
#       <td id="T_914b4_row11_col1" class="data row11 col1" >2965.5626</td>
#       <td id="T_914b4_row11_col2" class="data row11 col2" >14.7669</td>
#       <td id="T_914b4_row11_col3" class="data row11 col3" >0.0493</td>
#       <td id="T_914b4_row11_col4" class="data row11 col4" >0.0772</td>
#       <td id="T_914b4_row11_col5" class="data row11 col5" >0.1724</td>
#     </tr>
#   </tbody>
# </table>

# %%
boosted_dt = exp1.ensemble_model(dt, method = 'Boosting')
# Out:
# <style type="text/css">
# #T_09565_row10_col0, #T_09565_row10_col1, #T_09565_row10_col2, #T_09565_row10_col3, #T_09565_row10_col4, #T_09565_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_09565">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09565_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_09565_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_09565_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_09565_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_09565_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_09565_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09565_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09565_row0_col0" class="data row0 col0" >68.0794</td>
#       <td id="T_09565_row0_col1" class="data row0 col1" >8492.0159</td>
#       <td id="T_09565_row0_col2" class="data row0 col2" >92.1521</td>
#       <td id="T_09565_row0_col3" class="data row0 col3" >0.7524</td>
#       <td id="T_09565_row0_col4" class="data row0 col4" >0.5366</td>
#       <td id="T_09565_row0_col5" class="data row0 col5" >0.6374</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09565_row1_col0" class="data row1 col0" >60.5873</td>
#       <td id="T_09565_row1_col1" class="data row1 col1" >8611.0952</td>
#       <td id="T_09565_row1_col2" class="data row1 col2" >92.7960</td>
#       <td id="T_09565_row1_col3" class="data row1 col3" >0.7448</td>
#       <td id="T_09565_row1_col4" class="data row1 col4" >0.5371</td>
#       <td id="T_09565_row1_col5" class="data row1 col5" >0.5817</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09565_row2_col0" class="data row2 col0" >43.2222</td>
#       <td id="T_09565_row2_col1" class="data row2 col1" >4968.3651</td>
#       <td id="T_09565_row2_col2" class="data row2 col2" >70.4866</td>
#       <td id="T_09565_row2_col3" class="data row2 col3" >0.8743</td>
#       <td id="T_09565_row2_col4" class="data row2 col4" >0.5476</td>
#       <td id="T_09565_row2_col5" class="data row2 col5" >0.5745</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09565_row3_col0" class="data row3 col0" >75.0794</td>
#       <td id="T_09565_row3_col1" class="data row3 col1" >14607.2063</td>
#       <td id="T_09565_row3_col2" class="data row3 col2" >120.8603</td>
#       <td id="T_09565_row3_col3" class="data row3 col3" >0.7218</td>
#       <td id="T_09565_row3_col4" class="data row3 col4" >0.5577</td>
#       <td id="T_09565_row3_col5" class="data row3 col5" >0.5595</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09565_row4_col0" class="data row4 col0" >71.8254</td>
#       <td id="T_09565_row4_col1" class="data row4 col1" >11310.9683</td>
#       <td id="T_09565_row4_col2" class="data row4 col2" >106.3530</td>
#       <td id="T_09565_row4_col3" class="data row4 col3" >0.6830</td>
#       <td id="T_09565_row4_col4" class="data row4 col4" >0.6584</td>
#       <td id="T_09565_row4_col5" class="data row4 col5" >0.8325</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_09565_row5_col0" class="data row5 col0" >60.9365</td>
#       <td id="T_09565_row5_col1" class="data row5 col1" >9716.7460</td>
#       <td id="T_09565_row5_col2" class="data row5 col2" >98.5736</td>
#       <td id="T_09565_row5_col3" class="data row5 col3" >0.6471</td>
#       <td id="T_09565_row5_col4" class="data row5 col4" >0.6855</td>
#       <td id="T_09565_row5_col5" class="data row5 col5" >0.8059</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_09565_row6_col0" class="data row6 col0" >82.9048</td>
#       <td id="T_09565_row6_col1" class="data row6 col1" >17890.0476</td>
#       <td id="T_09565_row6_col2" class="data row6 col2" >133.7537</td>
#       <td id="T_09565_row6_col3" class="data row6 col3" >0.5795</td>
#       <td id="T_09565_row6_col4" class="data row6 col4" >0.6160</td>
#       <td id="T_09565_row6_col5" class="data row6 col5" >0.6395</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_09565_row7_col0" class="data row7 col0" >55.9683</td>
#       <td id="T_09565_row7_col1" class="data row7 col1" >7963.0794</td>
#       <td id="T_09565_row7_col2" class="data row7 col2" >89.2361</td>
#       <td id="T_09565_row7_col3" class="data row7 col3" >0.7711</td>
#       <td id="T_09565_row7_col4" class="data row7 col4" >0.4628</td>
#       <td id="T_09565_row7_col5" class="data row7 col5" >0.4580</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_09565_row8_col0" class="data row8 col0" >55.9683</td>
#       <td id="T_09565_row8_col1" class="data row8 col1" >6698.8571</td>
#       <td id="T_09565_row8_col2" class="data row8 col2" >81.8465</td>
#       <td id="T_09565_row8_col3" class="data row8 col3" >0.6684</td>
#       <td id="T_09565_row8_col4" class="data row8 col4" >0.6435</td>
#       <td id="T_09565_row8_col5" class="data row8 col5" >0.7684</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_09565_row9_col0" class="data row9 col0" >65.4762</td>
#       <td id="T_09565_row9_col1" class="data row9 col1" >8022.3016</td>
#       <td id="T_09565_row9_col2" class="data row9 col2" >89.5673</td>
#       <td id="T_09565_row9_col3" class="data row9 col3" >0.7460</td>
#       <td id="T_09565_row9_col4" class="data row9 col4" >0.6566</td>
#       <td id="T_09565_row9_col5" class="data row9 col5" >0.9671</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_09565_row10_col0" class="data row10 col0" >64.0048</td>
#       <td id="T_09565_row10_col1" class="data row10 col1" >9828.0683</td>
#       <td id="T_09565_row10_col2" class="data row10 col2" >97.5625</td>
#       <td id="T_09565_row10_col3" class="data row10 col3" >0.7188</td>
#       <td id="T_09565_row10_col4" class="data row10 col4" >0.5902</td>
#       <td id="T_09565_row10_col5" class="data row10 col5" >0.6824</td>
#     </tr>
#     <tr>
#       <th id="T_09565_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_09565_row11_col0" class="data row11 col0" >10.6863</td>
#       <td id="T_09565_row11_col1" class="data row11 col1" >3653.2283</td>
#       <td id="T_09565_row11_col2" class="data row11 col2" >17.5961</td>
#       <td id="T_09565_row11_col3" class="data row11 col3" >0.0760</td>
#       <td id="T_09565_row11_col4" class="data row11 col4" >0.0681</td>
#       <td id="T_09565_row11_col5" class="data row11 col5" >0.1474</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Blending and Stacking
#
# * **Blend** trains a Voting Regressor for select models passed in the estimator_list param. It creates multiple models and then averages the individual predictions to form a final prediction.
#
#
# * **Stack** trains a meta model over select estimators passed in the estimator_list parameter. Stacking is another popular technique for ensembling but is less commonly implemented due to practical difficulties. Stacking is an ensemble learning technique that combines multiple models via a meta-model. Another way to think about stacking is that multiple models are trained to predict the outcome and a meta-model is created that uses the predictions from those models as an input along with the original features. The implementation of stack_models() is based on Wolpert, D. H. (1992b). Stacked generalization

# %%
top3_exp1
# Out:
# [CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False),
#  LGBMRegressor(n_jobs=-1, random_state=555),
#  XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=-1, num_parallel_tree=None, ...)]

# %%
blender = exp1.blend_models(estimator_list = top3_exp1)
# you can use any mix of models:) for example ['rf','xgboost', 'lr']
# Out:
# <style type="text/css">
# #T_cd61d_row10_col0, #T_cd61d_row10_col1, #T_cd61d_row10_col2, #T_cd61d_row10_col3, #T_cd61d_row10_col4, #T_cd61d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cd61d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd61d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cd61d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cd61d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cd61d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cd61d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cd61d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd61d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd61d_row0_col0" class="data row0 col0" >53.1158</td>
#       <td id="T_cd61d_row0_col1" class="data row0 col1" >5238.6245</td>
#       <td id="T_cd61d_row0_col2" class="data row0 col2" >72.3783</td>
#       <td id="T_cd61d_row0_col3" class="data row0 col3" >0.8473</td>
#       <td id="T_cd61d_row0_col4" class="data row0 col4" >0.6338</td>
#       <td id="T_cd61d_row0_col5" class="data row0 col5" >0.7484</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd61d_row1_col0" class="data row1 col0" >41.1669</td>
#       <td id="T_cd61d_row1_col1" class="data row1 col1" >3090.1347</td>
#       <td id="T_cd61d_row1_col2" class="data row1 col2" >55.5890</td>
#       <td id="T_cd61d_row1_col3" class="data row1 col3" >0.9084</td>
#       <td id="T_cd61d_row1_col4" class="data row1 col4" >0.6428</td>
#       <td id="T_cd61d_row1_col5" class="data row1 col5" >0.7412</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd61d_row2_col0" class="data row2 col0" >42.0857</td>
#       <td id="T_cd61d_row2_col1" class="data row2 col1" >3446.2200</td>
#       <td id="T_cd61d_row2_col2" class="data row2 col2" >58.7045</td>
#       <td id="T_cd61d_row2_col3" class="data row2 col3" >0.9128</td>
#       <td id="T_cd61d_row2_col4" class="data row2 col4" >0.5687</td>
#       <td id="T_cd61d_row2_col5" class="data row2 col5" >0.6097</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd61d_row3_col0" class="data row3 col0" >56.5777</td>
#       <td id="T_cd61d_row3_col1" class="data row3 col1" >6070.4164</td>
#       <td id="T_cd61d_row3_col2" class="data row3 col2" >77.9129</td>
#       <td id="T_cd61d_row3_col3" class="data row3 col3" >0.8844</td>
#       <td id="T_cd61d_row3_col4" class="data row3 col4" >0.4183</td>
#       <td id="T_cd61d_row3_col5" class="data row3 col5" >0.4376</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd61d_row4_col0" class="data row4 col0" >49.5876</td>
#       <td id="T_cd61d_row4_col1" class="data row4 col1" >5228.9226</td>
#       <td id="T_cd61d_row4_col2" class="data row4 col2" >72.3113</td>
#       <td id="T_cd61d_row4_col3" class="data row4 col3" >0.8534</td>
#       <td id="T_cd61d_row4_col4" class="data row4 col4" >0.5673</td>
#       <td id="T_cd61d_row4_col5" class="data row4 col5" >0.8124</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cd61d_row5_col0" class="data row5 col0" >40.5629</td>
#       <td id="T_cd61d_row5_col1" class="data row5 col1" >3788.3785</td>
#       <td id="T_cd61d_row5_col2" class="data row5 col2" >61.5498</td>
#       <td id="T_cd61d_row5_col3" class="data row5 col3" >0.8624</td>
#       <td id="T_cd61d_row5_col4" class="data row5 col4" >0.5808</td>
#       <td id="T_cd61d_row5_col5" class="data row5 col5" >0.6898</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cd61d_row6_col0" class="data row6 col0" >60.4871</td>
#       <td id="T_cd61d_row6_col1" class="data row6 col1" >7894.9291</td>
#       <td id="T_cd61d_row6_col2" class="data row6 col2" >88.8534</td>
#       <td id="T_cd61d_row6_col3" class="data row6 col3" >0.8144</td>
#       <td id="T_cd61d_row6_col4" class="data row6 col4" >0.6121</td>
#       <td id="T_cd61d_row6_col5" class="data row6 col5" >0.7573</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cd61d_row7_col0" class="data row7 col0" >48.1249</td>
#       <td id="T_cd61d_row7_col1" class="data row7 col1" >5632.0556</td>
#       <td id="T_cd61d_row7_col2" class="data row7 col2" >75.0470</td>
#       <td id="T_cd61d_row7_col3" class="data row7 col3" >0.8381</td>
#       <td id="T_cd61d_row7_col4" class="data row7 col4" >0.5185</td>
#       <td id="T_cd61d_row7_col5" class="data row7 col5" >0.5062</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cd61d_row8_col0" class="data row8 col0" >44.9761</td>
#       <td id="T_cd61d_row8_col1" class="data row8 col1" >3725.7493</td>
#       <td id="T_cd61d_row8_col2" class="data row8 col2" >61.0389</td>
#       <td id="T_cd61d_row8_col3" class="data row8 col3" >0.8155</td>
#       <td id="T_cd61d_row8_col4" class="data row8 col4" >0.6666</td>
#       <td id="T_cd61d_row8_col5" class="data row8 col5" >0.9286</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cd61d_row9_col0" class="data row9 col0" >40.0013</td>
#       <td id="T_cd61d_row9_col1" class="data row9 col1" >3233.5997</td>
#       <td id="T_cd61d_row9_col2" class="data row9 col2" >56.8647</td>
#       <td id="T_cd61d_row9_col3" class="data row9 col3" >0.8976</td>
#       <td id="T_cd61d_row9_col4" class="data row9 col4" >0.4862</td>
#       <td id="T_cd61d_row9_col5" class="data row9 col5" >0.6295</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cd61d_row10_col0" class="data row10 col0" >47.6686</td>
#       <td id="T_cd61d_row10_col1" class="data row10 col1" >4734.9030</td>
#       <td id="T_cd61d_row10_col2" class="data row10 col2" >68.0250</td>
#       <td id="T_cd61d_row10_col3" class="data row10 col3" >0.8634</td>
#       <td id="T_cd61d_row10_col4" class="data row10 col4" >0.5695</td>
#       <td id="T_cd61d_row10_col5" class="data row10 col5" >0.6861</td>
#     </tr>
#     <tr>
#       <th id="T_cd61d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cd61d_row11_col0" class="data row11 col0" >6.8353</td>
#       <td id="T_cd61d_row11_col1" class="data row11 col1" >1469.9052</td>
#       <td id="T_cd61d_row11_col2" class="data row11 col2" >10.3684</td>
#       <td id="T_cd61d_row11_col3" class="data row11 col3" >0.0343</td>
#       <td id="T_cd61d_row11_col4" class="data row11 col4" >0.0730</td>
#       <td id="T_cd61d_row11_col5" class="data row11 col5" >0.1378</td>
#     </tr>
#   </tbody>
# </table>

# %%
blender
# Out:
# VotingRegressor(estimators=[('CatBoost Regressor',
#                              CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                             ('Light Gradient Boosting Machine',
#                              LGBMRegressor(n_jobs=-1, random_state=555)),
#                             ('Extreme Gradient Boosting',
#                              XGBRegressor(base_score=None, booster='gbtree',
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_...
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=-1,
#                                           num_parallel_tree=None, ...))],
#                 n_jobs=-1)

# %% [markdown]
# Now that we have created a VotingRegressor using the blend_models() function. The model returned by the blend_models function is just like any other model that you would create using create_model() or tune_model(). You can use this model for predictions on unseen data using predict_model() in the same way you would for any other model.

# %%
stacker = exp1.stack_models(estimator_list=top3_exp1)
# Out:
# <style type="text/css">
# #T_eefed_row10_col0, #T_eefed_row10_col1, #T_eefed_row10_col2, #T_eefed_row10_col3, #T_eefed_row10_col4, #T_eefed_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eefed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eefed_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eefed_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eefed_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eefed_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eefed_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eefed_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eefed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eefed_row0_col0" class="data row0 col0" >47.4907</td>
#       <td id="T_eefed_row0_col1" class="data row0 col1" >4168.4139</td>
#       <td id="T_eefed_row0_col2" class="data row0 col2" >64.5633</td>
#       <td id="T_eefed_row0_col3" class="data row0 col3" >0.8785</td>
#       <td id="T_eefed_row0_col4" class="data row0 col4" >0.6428</td>
#       <td id="T_eefed_row0_col5" class="data row0 col5" >1.0864</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eefed_row1_col0" class="data row1 col0" >38.7102</td>
#       <td id="T_eefed_row1_col1" class="data row1 col1" >2493.2281</td>
#       <td id="T_eefed_row1_col2" class="data row1 col2" >49.9322</td>
#       <td id="T_eefed_row1_col3" class="data row1 col3" >0.9261</td>
#       <td id="T_eefed_row1_col4" class="data row1 col4" >0.8098</td>
#       <td id="T_eefed_row1_col5" class="data row1 col5" >1.0388</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eefed_row2_col0" class="data row2 col0" >40.1655</td>
#       <td id="T_eefed_row2_col1" class="data row2 col1" >3372.9588</td>
#       <td id="T_eefed_row2_col2" class="data row2 col2" >58.0772</td>
#       <td id="T_eefed_row2_col3" class="data row2 col3" >0.9146</td>
#       <td id="T_eefed_row2_col4" class="data row2 col4" >0.5496</td>
#       <td id="T_eefed_row2_col5" class="data row2 col5" >0.7442</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eefed_row3_col0" class="data row3 col0" >50.3394</td>
#       <td id="T_eefed_row3_col1" class="data row3 col1" >4639.0467</td>
#       <td id="T_eefed_row3_col2" class="data row3 col2" >68.1105</td>
#       <td id="T_eefed_row3_col3" class="data row3 col3" >0.9116</td>
#       <td id="T_eefed_row3_col4" class="data row3 col4" >0.6221</td>
#       <td id="T_eefed_row3_col5" class="data row3 col5" >0.5117</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eefed_row4_col0" class="data row4 col0" >47.7989</td>
#       <td id="T_eefed_row4_col1" class="data row4 col1" >4517.1005</td>
#       <td id="T_eefed_row4_col2" class="data row4 col2" >67.2094</td>
#       <td id="T_eefed_row4_col3" class="data row4 col3" >0.8734</td>
#       <td id="T_eefed_row4_col4" class="data row4 col4" >0.5934</td>
#       <td id="T_eefed_row4_col5" class="data row4 col5" >0.7320</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eefed_row5_col0" class="data row5 col0" >42.0517</td>
#       <td id="T_eefed_row5_col1" class="data row5 col1" >2927.2044</td>
#       <td id="T_eefed_row5_col2" class="data row5 col2" >54.1036</td>
#       <td id="T_eefed_row5_col3" class="data row5 col3" >0.8937</td>
#       <td id="T_eefed_row5_col4" class="data row5 col4" >0.6631</td>
#       <td id="T_eefed_row5_col5" class="data row5 col5" >0.8368</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eefed_row6_col0" class="data row6 col0" >51.1846</td>
#       <td id="T_eefed_row6_col1" class="data row6 col1" >5342.5200</td>
#       <td id="T_eefed_row6_col2" class="data row6 col2" >73.0925</td>
#       <td id="T_eefed_row6_col3" class="data row6 col3" >0.8744</td>
#       <td id="T_eefed_row6_col4" class="data row6 col4" >0.6980</td>
#       <td id="T_eefed_row6_col5" class="data row6 col5" >0.8283</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eefed_row7_col0" class="data row7 col0" >46.6352</td>
#       <td id="T_eefed_row7_col1" class="data row7 col1" >5090.8089</td>
#       <td id="T_eefed_row7_col2" class="data row7 col2" >71.3499</td>
#       <td id="T_eefed_row7_col3" class="data row7 col3" >0.8537</td>
#       <td id="T_eefed_row7_col4" class="data row7 col4" >0.7016</td>
#       <td id="T_eefed_row7_col5" class="data row7 col5" >0.7098</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eefed_row8_col0" class="data row8 col0" >41.1069</td>
#       <td id="T_eefed_row8_col1" class="data row8 col1" >3352.8530</td>
#       <td id="T_eefed_row8_col2" class="data row8 col2" >57.9038</td>
#       <td id="T_eefed_row8_col3" class="data row8 col3" >0.8340</td>
#       <td id="T_eefed_row8_col4" class="data row8 col4" >0.6896</td>
#       <td id="T_eefed_row8_col5" class="data row8 col5" >0.9720</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eefed_row9_col0" class="data row9 col0" >37.4343</td>
#       <td id="T_eefed_row9_col1" class="data row9 col1" >2578.4340</td>
#       <td id="T_eefed_row9_col2" class="data row9 col2" >50.7783</td>
#       <td id="T_eefed_row9_col3" class="data row9 col3" >0.9184</td>
#       <td id="T_eefed_row9_col4" class="data row9 col4" >0.5894</td>
#       <td id="T_eefed_row9_col5" class="data row9 col5" >0.5944</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eefed_row10_col0" class="data row10 col0" >44.2917</td>
#       <td id="T_eefed_row10_col1" class="data row10 col1" >3848.2568</td>
#       <td id="T_eefed_row10_col2" class="data row10 col2" >61.5121</td>
#       <td id="T_eefed_row10_col3" class="data row10 col3" >0.8878</td>
#       <td id="T_eefed_row10_col4" class="data row10 col4" >0.6559</td>
#       <td id="T_eefed_row10_col5" class="data row10 col5" >0.8054</td>
#     </tr>
#     <tr>
#       <th id="T_eefed_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_eefed_row11_col0" class="data row11 col0" >4.7167</td>
#       <td id="T_eefed_row11_col1" class="data row11 col1" >985.9099</td>
#       <td id="T_eefed_row11_col2" class="data row11 col2" >8.0325</td>
#       <td id="T_eefed_row11_col3" class="data row11 col3" >0.0287</td>
#       <td id="T_eefed_row11_col4" class="data row11 col4" >0.0705</td>
#       <td id="T_eefed_row11_col5" class="data row11 col5" >0.1766</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  !!! It's always good to look at the standard deviation of CV results

# %%
stacker
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('CatBoost Regressor',
#                                CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                               ('Light Gradient Boosting Machine',
#                                LGBMRegressor(n_jobs=-1, random_state=555)),
#                               ('Extreme Gradient Boosting',
#                                XGBRegressor(base_score=None, booster='gbtree',
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             col...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=-1,
#                                             num_parallel_tree=None, ...))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1)

# %% [markdown]
# By default, the meta model (final model to generate predictions) is Linear Regression. The meta model can be changed using the meta_model parameter. See an example below:

# %%
xgboost = exp1.create_model('xgboost')
stacker_xgboost = exp1.stack_models(top3_exp1, meta_model = xgboost)
# Out:
# <style type="text/css">
# #T_4a948_row10_col0, #T_4a948_row10_col1, #T_4a948_row10_col2, #T_4a948_row10_col3, #T_4a948_row10_col4, #T_4a948_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4a948">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a948_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4a948_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4a948_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4a948_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4a948_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4a948_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a948_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a948_row0_col0" class="data row0 col0" >60.2139</td>
#       <td id="T_4a948_row0_col1" class="data row0 col1" >6766.7129</td>
#       <td id="T_4a948_row0_col2" class="data row0 col2" >82.2600</td>
#       <td id="T_4a948_row0_col3" class="data row0 col3" >0.8027</td>
#       <td id="T_4a948_row0_col4" class="data row0 col4" >0.6134</td>
#       <td id="T_4a948_row0_col5" class="data row0 col5" >0.6000</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a948_row1_col0" class="data row1 col0" >49.4707</td>
#       <td id="T_4a948_row1_col1" class="data row1 col1" >3796.8044</td>
#       <td id="T_4a948_row1_col2" class="data row1 col2" >61.6182</td>
#       <td id="T_4a948_row1_col3" class="data row1 col3" >0.8875</td>
#       <td id="T_4a948_row1_col4" class="data row1 col4" >0.7120</td>
#       <td id="T_4a948_row1_col5" class="data row1 col5" >0.9281</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a948_row2_col0" class="data row2 col0" >46.9345</td>
#       <td id="T_4a948_row2_col1" class="data row2 col1" >4240.5688</td>
#       <td id="T_4a948_row2_col2" class="data row2 col2" >65.1197</td>
#       <td id="T_4a948_row2_col3" class="data row2 col3" >0.8927</td>
#       <td id="T_4a948_row2_col4" class="data row2 col4" >0.5473</td>
#       <td id="T_4a948_row2_col5" class="data row2 col5" >0.5040</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a948_row3_col0" class="data row3 col0" >64.8810</td>
#       <td id="T_4a948_row3_col1" class="data row3 col1" >8308.1787</td>
#       <td id="T_4a948_row3_col2" class="data row3 col2" >91.1492</td>
#       <td id="T_4a948_row3_col3" class="data row3 col3" >0.8418</td>
#       <td id="T_4a948_row3_col4" class="data row3 col4" >0.4728</td>
#       <td id="T_4a948_row3_col5" class="data row3 col5" >0.5030</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a948_row4_col0" class="data row4 col0" >58.0069</td>
#       <td id="T_4a948_row4_col1" class="data row4 col1" >6719.9502</td>
#       <td id="T_4a948_row4_col2" class="data row4 col2" >81.9753</td>
#       <td id="T_4a948_row4_col3" class="data row4 col3" >0.8116</td>
#       <td id="T_4a948_row4_col4" class="data row4 col4" >0.6108</td>
#       <td id="T_4a948_row4_col5" class="data row4 col5" >1.0076</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a948_row5_col0" class="data row5 col0" >45.6802</td>
#       <td id="T_4a948_row5_col1" class="data row5 col1" >4838.3247</td>
#       <td id="T_4a948_row5_col2" class="data row5 col2" >69.5581</td>
#       <td id="T_4a948_row5_col3" class="data row5 col3" >0.8243</td>
#       <td id="T_4a948_row5_col4" class="data row5 col4" >0.6518</td>
#       <td id="T_4a948_row5_col5" class="data row5 col5" >0.6953</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a948_row6_col0" class="data row6 col0" >67.8975</td>
#       <td id="T_4a948_row6_col1" class="data row6 col1" >10454.5977</td>
#       <td id="T_4a948_row6_col2" class="data row6 col2" >102.2477</td>
#       <td id="T_4a948_row6_col3" class="data row6 col3" >0.7542</td>
#       <td id="T_4a948_row6_col4" class="data row6 col4" >0.6080</td>
#       <td id="T_4a948_row6_col5" class="data row6 col5" >0.7638</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a948_row7_col0" class="data row7 col0" >49.0900</td>
#       <td id="T_4a948_row7_col1" class="data row7 col1" >5928.1665</td>
#       <td id="T_4a948_row7_col2" class="data row7 col2" >76.9946</td>
#       <td id="T_4a948_row7_col3" class="data row7 col3" >0.8296</td>
#       <td id="T_4a948_row7_col4" class="data row7 col4" >0.5125</td>
#       <td id="T_4a948_row7_col5" class="data row7 col5" >0.5153</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a948_row8_col0" class="data row8 col0" >56.5052</td>
#       <td id="T_4a948_row8_col1" class="data row8 col1" >5271.0254</td>
#       <td id="T_4a948_row8_col2" class="data row8 col2" >72.6018</td>
#       <td id="T_4a948_row8_col3" class="data row8 col3" >0.7390</td>
#       <td id="T_4a948_row8_col4" class="data row8 col4" >0.7446</td>
#       <td id="T_4a948_row8_col5" class="data row8 col5" >1.1929</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a948_row9_col0" class="data row9 col0" >50.8728</td>
#       <td id="T_4a948_row9_col1" class="data row9 col1" >5138.9683</td>
#       <td id="T_4a948_row9_col2" class="data row9 col2" >71.6866</td>
#       <td id="T_4a948_row9_col3" class="data row9 col3" >0.8373</td>
#       <td id="T_4a948_row9_col4" class="data row9 col4" >0.5645</td>
#       <td id="T_4a948_row9_col5" class="data row9 col5" >0.5706</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4a948_row10_col0" class="data row10 col0" >54.9553</td>
#       <td id="T_4a948_row10_col1" class="data row10 col1" >6146.3298</td>
#       <td id="T_4a948_row10_col2" class="data row10 col2" >77.5211</td>
#       <td id="T_4a948_row10_col3" class="data row10 col3" >0.8221</td>
#       <td id="T_4a948_row10_col4" class="data row10 col4" >0.6038</td>
#       <td id="T_4a948_row10_col5" class="data row10 col5" >0.7281</td>
#     </tr>
#     <tr>
#       <th id="T_4a948_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4a948_row11_col0" class="data row11 col0" >7.3273</td>
#       <td id="T_4a948_row11_col1" class="data row11 col1" >1914.1651</td>
#       <td id="T_4a948_row11_col2" class="data row11 col2" >11.6964</td>
#       <td id="T_4a948_row11_col3" class="data row11 col3" >0.0468</td>
#       <td id="T_4a948_row11_col4" class="data row11 col4" >0.0801</td>
#       <td id="T_4a948_row11_col5" class="data row11 col5" >0.2289</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ef99d_row10_col0, #T_ef99d_row10_col1, #T_ef99d_row10_col2, #T_ef99d_row10_col3, #T_ef99d_row10_col4, #T_ef99d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ef99d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef99d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ef99d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ef99d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ef99d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ef99d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ef99d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef99d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef99d_row0_col0" class="data row0 col0" >66.4078</td>
#       <td id="T_ef99d_row0_col1" class="data row0 col1" >8190.4077</td>
#       <td id="T_ef99d_row0_col2" class="data row0 col2" >90.5009</td>
#       <td id="T_ef99d_row0_col3" class="data row0 col3" >0.7612</td>
#       <td id="T_ef99d_row0_col4" class="data row0 col4" >0.5095</td>
#       <td id="T_ef99d_row0_col5" class="data row0 col5" >0.5383</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef99d_row1_col0" class="data row1 col0" >41.3071</td>
#       <td id="T_ef99d_row1_col1" class="data row1 col1" >3532.1804</td>
#       <td id="T_ef99d_row1_col2" class="data row1 col2" >59.4321</td>
#       <td id="T_ef99d_row1_col3" class="data row1 col3" >0.8953</td>
#       <td id="T_ef99d_row1_col4" class="data row1 col4" >0.7452</td>
#       <td id="T_ef99d_row1_col5" class="data row1 col5" >0.9217</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef99d_row2_col0" class="data row2 col0" >64.5377</td>
#       <td id="T_ef99d_row2_col1" class="data row2 col1" >8956.7197</td>
#       <td id="T_ef99d_row2_col2" class="data row2 col2" >94.6399</td>
#       <td id="T_ef99d_row2_col3" class="data row2 col3" >0.7734</td>
#       <td id="T_ef99d_row2_col4" class="data row2 col4" >0.5894</td>
#       <td id="T_ef99d_row2_col5" class="data row2 col5" >0.7362</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef99d_row3_col0" class="data row3 col0" >51.3384</td>
#       <td id="T_ef99d_row3_col1" class="data row3 col1" >5884.1401</td>
#       <td id="T_ef99d_row3_col2" class="data row3 col2" >76.7082</td>
#       <td id="T_ef99d_row3_col3" class="data row3 col3" >0.8879</td>
#       <td id="T_ef99d_row3_col4" class="data row3 col4" >0.5451</td>
#       <td id="T_ef99d_row3_col5" class="data row3 col5" >0.4261</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef99d_row4_col0" class="data row4 col0" >53.7895</td>
#       <td id="T_ef99d_row4_col1" class="data row4 col1" >5238.0220</td>
#       <td id="T_ef99d_row4_col2" class="data row4 col2" >72.3742</td>
#       <td id="T_ef99d_row4_col3" class="data row4 col3" >0.8532</td>
#       <td id="T_ef99d_row4_col4" class="data row4 col4" >0.5992</td>
#       <td id="T_ef99d_row4_col5" class="data row4 col5" >0.7847</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ef99d_row5_col0" class="data row5 col0" >42.7830</td>
#       <td id="T_ef99d_row5_col1" class="data row5 col1" >3533.0015</td>
#       <td id="T_ef99d_row5_col2" class="data row5 col2" >59.4391</td>
#       <td id="T_ef99d_row5_col3" class="data row5 col3" >0.8717</td>
#       <td id="T_ef99d_row5_col4" class="data row5 col4" >0.6785</td>
#       <td id="T_ef99d_row5_col5" class="data row5 col5" >0.8613</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ef99d_row6_col0" class="data row6 col0" >51.9906</td>
#       <td id="T_ef99d_row6_col1" class="data row6 col1" >5093.1099</td>
#       <td id="T_ef99d_row6_col2" class="data row6 col2" >71.3660</td>
#       <td id="T_ef99d_row6_col3" class="data row6 col3" >0.8803</td>
#       <td id="T_ef99d_row6_col4" class="data row6 col4" >0.6146</td>
#       <td id="T_ef99d_row6_col5" class="data row6 col5" >0.6406</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ef99d_row7_col0" class="data row7 col0" >58.5118</td>
#       <td id="T_ef99d_row7_col1" class="data row7 col1" >8242.3066</td>
#       <td id="T_ef99d_row7_col2" class="data row7 col2" >90.7871</td>
#       <td id="T_ef99d_row7_col3" class="data row7 col3" >0.7631</td>
#       <td id="T_ef99d_row7_col4" class="data row7 col4" >0.5541</td>
#       <td id="T_ef99d_row7_col5" class="data row7 col5" >0.6124</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ef99d_row8_col0" class="data row8 col0" >51.8067</td>
#       <td id="T_ef99d_row8_col1" class="data row8 col1" >5849.3647</td>
#       <td id="T_ef99d_row8_col2" class="data row8 col2" >76.4811</td>
#       <td id="T_ef99d_row8_col3" class="data row8 col3" >0.7104</td>
#       <td id="T_ef99d_row8_col4" class="data row8 col4" >0.6593</td>
#       <td id="T_ef99d_row8_col5" class="data row8 col5" >0.9292</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ef99d_row9_col0" class="data row9 col0" >39.8498</td>
#       <td id="T_ef99d_row9_col1" class="data row9 col1" >3517.2771</td>
#       <td id="T_ef99d_row9_col2" class="data row9 col2" >59.3066</td>
#       <td id="T_ef99d_row9_col3" class="data row9 col3" >0.8886</td>
#       <td id="T_ef99d_row9_col4" class="data row9 col4" >0.5254</td>
#       <td id="T_ef99d_row9_col5" class="data row9 col5" >0.5584</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ef99d_row10_col0" class="data row10 col0" >52.2322</td>
#       <td id="T_ef99d_row10_col1" class="data row10 col1" >5803.6530</td>
#       <td id="T_ef99d_row10_col2" class="data row10 col2" >75.1035</td>
#       <td id="T_ef99d_row10_col3" class="data row10 col3" >0.8285</td>
#       <td id="T_ef99d_row10_col4" class="data row10 col4" >0.6020</td>
#       <td id="T_ef99d_row10_col5" class="data row10 col5" >0.7009</td>
#     </tr>
#     <tr>
#       <th id="T_ef99d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ef99d_row11_col0" class="data row11 col0" >8.7020</td>
#       <td id="T_ef99d_row11_col1" class="data row11 col1" >1948.3788</td>
#       <td id="T_ef99d_row11_col2" class="data row11 col2" >12.7716</td>
#       <td id="T_ef99d_row11_col3" class="data row11 col3" >0.0652</td>
#       <td id="T_ef99d_row11_col4" class="data row11 col4" >0.0707</td>
#       <td id="T_ef99d_row11_col5" class="data row11 col5" >0.1639</td>
#     </tr>
#   </tbody>
# </table>

# %%
stacker_xgboost
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('CatBoost Regressor',
#                                CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                               ('Light Gradient Boosting Machine',
#                                LGBMRegressor(n_jobs=-1, random_state=555)),
#                               ('Extreme Gradient Boosting',
#                                XGBRegressor(base_score=None, booster='gbtree',
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             col...
#                                                feature_weights=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=None, max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=None, max_leaves=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=None, n_jobs=-1,
#                                                num_parallel_tree=None, ...),
#                   n_jobs=-1)

# %% [markdown]
# Before we wrap up this section, there is another parameter in stack_models() that we haven't seen yet called restack. This parameter controls the ability to expose the raw data to the meta model. When set to True, it exposes the raw data to the meta model along with all the predictions of the base level models. By default it is set to True

# %% [markdown]
# ## AutoML
#
# This function returns the best model out of all trained models in current session based on the optimize parameter. Metrics evaluated can be accessed using the get_metrics function.
#
# *I don't recommend doing it this way! very slow!*

# %%
# CatBoost >= 1.2.6 rejects NumPy integers in scikit-learn's clone(), which breaks PyCaret's default
# CatBoost tuning grid on Google Colab. If CatBoost is among the models, tune it with a custom grid
# of plain Python numbers instead (the other models keep PyCaret's default grid).
catboost_grid = {
    'depth':        [4, 6, 8, 10],
    'eta':          [0.01, 0.05, 0.1, 0.3],   # learning rate
    'n_estimators': [100, 200, 300, 500],
    'l2_leaf_reg':  [1, 3, 5, 10],
}

# %%
# we already have top3_expr1, blender and stacker so far. Let's make tuned_top3_expr1 and pick the best one.

tuned_top3_expr = [
    exp1.tune_model(i, custom_grid=catboost_grid if 'CatBoost' in type(i).__name__ else None)
    for i in top3_exp1
]
best_R2_model = exp1.automl(optimize = 'R2')
# Out:
# <style type="text/css">
# #T_3a3b5_row10_col0, #T_3a3b5_row10_col1, #T_3a3b5_row10_col2, #T_3a3b5_row10_col3, #T_3a3b5_row10_col4, #T_3a3b5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3a3b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a3b5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3a3b5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3a3b5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3a3b5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3a3b5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3a3b5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a3b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a3b5_row0_col0" class="data row0 col0" >50.4321</td>
#       <td id="T_3a3b5_row0_col1" class="data row0 col1" >5237.0138</td>
#       <td id="T_3a3b5_row0_col2" class="data row0 col2" >72.3672</td>
#       <td id="T_3a3b5_row0_col3" class="data row0 col3" >0.8473</td>
#       <td id="T_3a3b5_row0_col4" class="data row0 col4" >0.6630</td>
#       <td id="T_3a3b5_row0_col5" class="data row0 col5" >1.4293</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a3b5_row1_col0" class="data row1 col0" >42.2053</td>
#       <td id="T_3a3b5_row1_col1" class="data row1 col1" >3001.2267</td>
#       <td id="T_3a3b5_row1_col2" class="data row1 col2" >54.7835</td>
#       <td id="T_3a3b5_row1_col3" class="data row1 col3" >0.9110</td>
#       <td id="T_3a3b5_row1_col4" class="data row1 col4" >0.8384</td>
#       <td id="T_3a3b5_row1_col5" class="data row1 col5" >1.1005</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a3b5_row2_col0" class="data row2 col0" >40.4198</td>
#       <td id="T_3a3b5_row2_col1" class="data row2 col1" >3304.6249</td>
#       <td id="T_3a3b5_row2_col2" class="data row2 col2" >57.4859</td>
#       <td id="T_3a3b5_row2_col3" class="data row2 col3" >0.9164</td>
#       <td id="T_3a3b5_row2_col4" class="data row2 col4" >0.7413</td>
#       <td id="T_3a3b5_row2_col5" class="data row2 col5" >1.1367</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a3b5_row3_col0" class="data row3 col0" >45.8896</td>
#       <td id="T_3a3b5_row3_col1" class="data row3 col1" >4068.7250</td>
#       <td id="T_3a3b5_row3_col2" class="data row3 col2" >63.7866</td>
#       <td id="T_3a3b5_row3_col3" class="data row3 col3" >0.9225</td>
#       <td id="T_3a3b5_row3_col4" class="data row3 col4" >0.4425</td>
#       <td id="T_3a3b5_row3_col5" class="data row3 col5" >0.4235</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a3b5_row4_col0" class="data row4 col0" >48.0790</td>
#       <td id="T_3a3b5_row4_col1" class="data row4 col1" >4511.0748</td>
#       <td id="T_3a3b5_row4_col2" class="data row4 col2" >67.1645</td>
#       <td id="T_3a3b5_row4_col3" class="data row4 col3" >0.8736</td>
#       <td id="T_3a3b5_row4_col4" class="data row4 col4" >0.6801</td>
#       <td id="T_3a3b5_row4_col5" class="data row4 col5" >1.2558</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a3b5_row5_col0" class="data row5 col0" >38.2909</td>
#       <td id="T_3a3b5_row5_col1" class="data row5 col1" >2953.6172</td>
#       <td id="T_3a3b5_row5_col2" class="data row5 col2" >54.3472</td>
#       <td id="T_3a3b5_row5_col3" class="data row5 col3" >0.8927</td>
#       <td id="T_3a3b5_row5_col4" class="data row5 col4" >0.6728</td>
#       <td id="T_3a3b5_row5_col5" class="data row5 col5" >0.8773</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a3b5_row6_col0" class="data row6 col0" >52.1750</td>
#       <td id="T_3a3b5_row6_col1" class="data row6 col1" >6041.8980</td>
#       <td id="T_3a3b5_row6_col2" class="data row6 col2" >77.7296</td>
#       <td id="T_3a3b5_row6_col3" class="data row6 col3" >0.8580</td>
#       <td id="T_3a3b5_row6_col4" class="data row6 col4" >0.6975</td>
#       <td id="T_3a3b5_row6_col5" class="data row6 col5" >1.0146</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a3b5_row7_col0" class="data row7 col0" >43.5215</td>
#       <td id="T_3a3b5_row7_col1" class="data row7 col1" >4664.4402</td>
#       <td id="T_3a3b5_row7_col2" class="data row7 col2" >68.2967</td>
#       <td id="T_3a3b5_row7_col3" class="data row7 col3" >0.8659</td>
#       <td id="T_3a3b5_row7_col4" class="data row7 col4" >0.6934</td>
#       <td id="T_3a3b5_row7_col5" class="data row7 col5" >0.7880</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a3b5_row8_col0" class="data row8 col0" >40.0990</td>
#       <td id="T_3a3b5_row8_col1" class="data row8 col1" >3085.6843</td>
#       <td id="T_3a3b5_row8_col2" class="data row8 col2" >55.5489</td>
#       <td id="T_3a3b5_row8_col3" class="data row8 col3" >0.8472</td>
#       <td id="T_3a3b5_row8_col4" class="data row8 col4" >0.7369</td>
#       <td id="T_3a3b5_row8_col5" class="data row8 col5" >1.2971</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a3b5_row9_col0" class="data row9 col0" >39.7746</td>
#       <td id="T_3a3b5_row9_col1" class="data row9 col1" >2723.0237</td>
#       <td id="T_3a3b5_row9_col2" class="data row9 col2" >52.1826</td>
#       <td id="T_3a3b5_row9_col3" class="data row9 col3" >0.9138</td>
#       <td id="T_3a3b5_row9_col4" class="data row9 col4" >0.6164</td>
#       <td id="T_3a3b5_row9_col5" class="data row9 col5" >0.8665</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3a3b5_row10_col0" class="data row10 col0" >44.0887</td>
#       <td id="T_3a3b5_row10_col1" class="data row10 col1" >3959.1329</td>
#       <td id="T_3a3b5_row10_col2" class="data row10 col2" >62.3693</td>
#       <td id="T_3a3b5_row10_col3" class="data row10 col3" >0.8848</td>
#       <td id="T_3a3b5_row10_col4" class="data row10 col4" >0.6782</td>
#       <td id="T_3a3b5_row10_col5" class="data row10 col5" >1.0189</td>
#     </tr>
#     <tr>
#       <th id="T_3a3b5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3a3b5_row11_col0" class="data row11 col0" >4.5855</td>
#       <td id="T_3a3b5_row11_col1" class="data row11 col1" >1069.2476</td>
#       <td id="T_3a3b5_row11_col2" class="data row11 col2" >8.3191</td>
#       <td id="T_3a3b5_row11_col3" class="data row11 col3" >0.0283</td>
#       <td id="T_3a3b5_row11_col4" class="data row11 col4" >0.0966</td>
#       <td id="T_3a3b5_row11_col5" class="data row11 col5" >0.2781</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_df0a2_row10_col0, #T_df0a2_row10_col1, #T_df0a2_row10_col2, #T_df0a2_row10_col3, #T_df0a2_row10_col4, #T_df0a2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_df0a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df0a2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_df0a2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_df0a2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_df0a2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_df0a2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_df0a2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df0a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df0a2_row0_col0" class="data row0 col0" >64.8999</td>
#       <td id="T_df0a2_row0_col1" class="data row0 col1" >9053.8133</td>
#       <td id="T_df0a2_row0_col2" class="data row0 col2" >95.1515</td>
#       <td id="T_df0a2_row0_col3" class="data row0 col3" >0.7360</td>
#       <td id="T_df0a2_row0_col4" class="data row0 col4" >0.5996</td>
#       <td id="T_df0a2_row0_col5" class="data row0 col5" >0.7645</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df0a2_row1_col0" class="data row1 col0" >50.2466</td>
#       <td id="T_df0a2_row1_col1" class="data row1 col1" >4382.5597</td>
#       <td id="T_df0a2_row1_col2" class="data row1 col2" >66.2009</td>
#       <td id="T_df0a2_row1_col3" class="data row1 col3" >0.8701</td>
#       <td id="T_df0a2_row1_col4" class="data row1 col4" >0.7531</td>
#       <td id="T_df0a2_row1_col5" class="data row1 col5" >0.9413</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_df0a2_row2_col0" class="data row2 col0" >62.1049</td>
#       <td id="T_df0a2_row2_col1" class="data row2 col1" >7429.8571</td>
#       <td id="T_df0a2_row2_col2" class="data row2 col2" >86.1966</td>
#       <td id="T_df0a2_row2_col3" class="data row2 col3" >0.8120</td>
#       <td id="T_df0a2_row2_col4" class="data row2 col4" >0.8010</td>
#       <td id="T_df0a2_row2_col5" class="data row2 col5" >1.3925</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_df0a2_row3_col0" class="data row3 col0" >72.5285</td>
#       <td id="T_df0a2_row3_col1" class="data row3 col1" >8535.5372</td>
#       <td id="T_df0a2_row3_col2" class="data row3 col2" >92.3880</td>
#       <td id="T_df0a2_row3_col3" class="data row3 col3" >0.8374</td>
#       <td id="T_df0a2_row3_col4" class="data row3 col4" >0.7110</td>
#       <td id="T_df0a2_row3_col5" class="data row3 col5" >0.9283</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_df0a2_row4_col0" class="data row4 col0" >68.0816</td>
#       <td id="T_df0a2_row4_col1" class="data row4 col1" >8140.1655</td>
#       <td id="T_df0a2_row4_col2" class="data row4 col2" >90.2229</td>
#       <td id="T_df0a2_row4_col3" class="data row4 col3" >0.7718</td>
#       <td id="T_df0a2_row4_col4" class="data row4 col4" >0.7606</td>
#       <td id="T_df0a2_row4_col5" class="data row4 col5" >1.9563</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_df0a2_row5_col0" class="data row5 col0" >58.6140</td>
#       <td id="T_df0a2_row5_col1" class="data row5 col1" >6837.9134</td>
#       <td id="T_df0a2_row5_col2" class="data row5 col2" >82.6917</td>
#       <td id="T_df0a2_row5_col3" class="data row5 col3" >0.7517</td>
#       <td id="T_df0a2_row5_col4" class="data row5 col4" >0.8245</td>
#       <td id="T_df0a2_row5_col5" class="data row5 col5" >1.3846</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_df0a2_row6_col0" class="data row6 col0" >70.0213</td>
#       <td id="T_df0a2_row6_col1" class="data row6 col1" >10342.2379</td>
#       <td id="T_df0a2_row6_col2" class="data row6 col2" >101.6968</td>
#       <td id="T_df0a2_row6_col3" class="data row6 col3" >0.7569</td>
#       <td id="T_df0a2_row6_col4" class="data row6 col4" >0.6611</td>
#       <td id="T_df0a2_row6_col5" class="data row6 col5" >0.8049</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_df0a2_row7_col0" class="data row7 col0" >58.4534</td>
#       <td id="T_df0a2_row7_col1" class="data row7 col1" >6185.1057</td>
#       <td id="T_df0a2_row7_col2" class="data row7 col2" >78.6454</td>
#       <td id="T_df0a2_row7_col3" class="data row7 col3" >0.8222</td>
#       <td id="T_df0a2_row7_col4" class="data row7 col4" >0.9925</td>
#       <td id="T_df0a2_row7_col5" class="data row7 col5" >1.7542</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_df0a2_row8_col0" class="data row8 col0" >61.0609</td>
#       <td id="T_df0a2_row8_col1" class="data row8 col1" >6222.3347</td>
#       <td id="T_df0a2_row8_col2" class="data row8 col2" >78.8818</td>
#       <td id="T_df0a2_row8_col3" class="data row8 col3" >0.6919</td>
#       <td id="T_df0a2_row8_col4" class="data row8 col4" >0.8743</td>
#       <td id="T_df0a2_row8_col5" class="data row8 col5" >1.8909</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_df0a2_row9_col0" class="data row9 col0" >57.7657</td>
#       <td id="T_df0a2_row9_col1" class="data row9 col1" >5923.0258</td>
#       <td id="T_df0a2_row9_col2" class="data row9 col2" >76.9612</td>
#       <td id="T_df0a2_row9_col3" class="data row9 col3" >0.8125</td>
#       <td id="T_df0a2_row9_col4" class="data row9 col4" >0.5711</td>
#       <td id="T_df0a2_row9_col5" class="data row9 col5" >0.6636</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_df0a2_row10_col0" class="data row10 col0" >62.3777</td>
#       <td id="T_df0a2_row10_col1" class="data row10 col1" >7305.2550</td>
#       <td id="T_df0a2_row10_col2" class="data row10 col2" >84.9037</td>
#       <td id="T_df0a2_row10_col3" class="data row10 col3" >0.7863</td>
#       <td id="T_df0a2_row10_col4" class="data row10 col4" >0.7549</td>
#       <td id="T_df0a2_row10_col5" class="data row10 col5" >1.2481</td>
#     </tr>
#     <tr>
#       <th id="T_df0a2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_df0a2_row11_col0" class="data row11 col0" >6.3259</td>
#       <td id="T_df0a2_row11_col1" class="data row11 col1" >1661.4897</td>
#       <td id="T_df0a2_row11_col2" class="data row11 col2" >9.8296</td>
#       <td id="T_df0a2_row11_col3" class="data row11 col3" >0.0510</td>
#       <td id="T_df0a2_row11_col4" class="data row11 col4" >0.1210</td>
#       <td id="T_df0a2_row11_col5" class="data row11 col5" >0.4668</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_c8cc0_row10_col0, #T_c8cc0_row10_col1, #T_c8cc0_row10_col2, #T_c8cc0_row10_col3, #T_c8cc0_row10_col4, #T_c8cc0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c8cc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8cc0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c8cc0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c8cc0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c8cc0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c8cc0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c8cc0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8cc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8cc0_row0_col0" class="data row0 col0" >57.7093</td>
#       <td id="T_c8cc0_row0_col1" class="data row0 col1" >6264.3423</td>
#       <td id="T_c8cc0_row0_col2" class="data row0 col2" >79.1476</td>
#       <td id="T_c8cc0_row0_col3" class="data row0 col3" >0.8173</td>
#       <td id="T_c8cc0_row0_col4" class="data row0 col4" >0.5782</td>
#       <td id="T_c8cc0_row0_col5" class="data row0 col5" >0.8457</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8cc0_row1_col0" class="data row1 col0" >46.1732</td>
#       <td id="T_c8cc0_row1_col1" class="data row1 col1" >3947.6365</td>
#       <td id="T_c8cc0_row1_col2" class="data row1 col2" >62.8302</td>
#       <td id="T_c8cc0_row1_col3" class="data row1 col3" >0.8830</td>
#       <td id="T_c8cc0_row1_col4" class="data row1 col4" >0.7174</td>
#       <td id="T_c8cc0_row1_col5" class="data row1 col5" >0.9147</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8cc0_row2_col0" class="data row2 col0" >42.5686</td>
#       <td id="T_c8cc0_row2_col1" class="data row2 col1" >3403.8313</td>
#       <td id="T_c8cc0_row2_col2" class="data row2 col2" >58.3424</td>
#       <td id="T_c8cc0_row2_col3" class="data row2 col3" >0.9139</td>
#       <td id="T_c8cc0_row2_col4" class="data row2 col4" >0.5847</td>
#       <td id="T_c8cc0_row2_col5" class="data row2 col5" >0.7981</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8cc0_row3_col0" class="data row3 col0" >57.3572</td>
#       <td id="T_c8cc0_row3_col1" class="data row3 col1" >5977.6538</td>
#       <td id="T_c8cc0_row3_col2" class="data row3 col2" >77.3153</td>
#       <td id="T_c8cc0_row3_col3" class="data row3 col3" >0.8861</td>
#       <td id="T_c8cc0_row3_col4" class="data row3 col4" >0.5010</td>
#       <td id="T_c8cc0_row3_col5" class="data row3 col5" >0.5118</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8cc0_row4_col0" class="data row4 col0" >48.9163</td>
#       <td id="T_c8cc0_row4_col1" class="data row4 col1" >4445.7256</td>
#       <td id="T_c8cc0_row4_col2" class="data row4 col2" >66.6763</td>
#       <td id="T_c8cc0_row4_col3" class="data row4 col3" >0.8754</td>
#       <td id="T_c8cc0_row4_col4" class="data row4 col4" >0.6362</td>
#       <td id="T_c8cc0_row4_col5" class="data row4 col5" >1.0488</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8cc0_row5_col0" class="data row5 col0" >41.5291</td>
#       <td id="T_c8cc0_row5_col1" class="data row5 col1" >3537.5037</td>
#       <td id="T_c8cc0_row5_col2" class="data row5 col2" >59.4769</td>
#       <td id="T_c8cc0_row5_col3" class="data row5 col3" >0.8715</td>
#       <td id="T_c8cc0_row5_col4" class="data row5 col4" >0.7718</td>
#       <td id="T_c8cc0_row5_col5" class="data row5 col5" >0.9954</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8cc0_row6_col0" class="data row6 col0" >60.5404</td>
#       <td id="T_c8cc0_row6_col1" class="data row6 col1" >7547.4849</td>
#       <td id="T_c8cc0_row6_col2" class="data row6 col2" >86.8763</td>
#       <td id="T_c8cc0_row6_col3" class="data row6 col3" >0.8226</td>
#       <td id="T_c8cc0_row6_col4" class="data row6 col4" >0.6127</td>
#       <td id="T_c8cc0_row6_col5" class="data row6 col5" >0.7278</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8cc0_row7_col0" class="data row7 col0" >53.5661</td>
#       <td id="T_c8cc0_row7_col1" class="data row7 col1" >6503.1050</td>
#       <td id="T_c8cc0_row7_col2" class="data row7 col2" >80.6418</td>
#       <td id="T_c8cc0_row7_col3" class="data row7 col3" >0.8131</td>
#       <td id="T_c8cc0_row7_col4" class="data row7 col4" >0.6198</td>
#       <td id="T_c8cc0_row7_col5" class="data row7 col5" >0.8012</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8cc0_row8_col0" class="data row8 col0" >43.7117</td>
#       <td id="T_c8cc0_row8_col1" class="data row8 col1" >3548.4915</td>
#       <td id="T_c8cc0_row8_col2" class="data row8 col2" >59.5692</td>
#       <td id="T_c8cc0_row8_col3" class="data row8 col3" >0.8243</td>
#       <td id="T_c8cc0_row8_col4" class="data row8 col4" >0.6340</td>
#       <td id="T_c8cc0_row8_col5" class="data row8 col5" >0.9494</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8cc0_row9_col0" class="data row9 col0" >47.2593</td>
#       <td id="T_c8cc0_row9_col1" class="data row9 col1" >4301.8062</td>
#       <td id="T_c8cc0_row9_col2" class="data row9 col2" >65.5882</td>
#       <td id="T_c8cc0_row9_col3" class="data row9 col3" >0.8638</td>
#       <td id="T_c8cc0_row9_col4" class="data row9 col4" >0.5422</td>
#       <td id="T_c8cc0_row9_col5" class="data row9 col5" >0.7412</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c8cc0_row10_col0" class="data row10 col0" >49.9331</td>
#       <td id="T_c8cc0_row10_col1" class="data row10 col1" >4947.7581</td>
#       <td id="T_c8cc0_row10_col2" class="data row10 col2" >69.6464</td>
#       <td id="T_c8cc0_row10_col3" class="data row10 col3" >0.8571</td>
#       <td id="T_c8cc0_row10_col4" class="data row10 col4" >0.6198</td>
#       <td id="T_c8cc0_row10_col5" class="data row10 col5" >0.8334</td>
#     </tr>
#     <tr>
#       <th id="T_c8cc0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c8cc0_row11_col0" class="data row11 col0" >6.5360</td>
#       <td id="T_c8cc0_row11_col1" class="data row11 col1" >1413.2152</td>
#       <td id="T_c8cc0_row11_col2" class="data row11 col2" >9.8557</td>
#       <td id="T_c8cc0_row11_col3" class="data row11 col3" >0.0333</td>
#       <td id="T_c8cc0_row11_col4" class="data row11 col4" >0.0750</td>
#       <td id="T_c8cc0_row11_col5" class="data row11 col5" >0.1477</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
best_R2_model
# Out:
# CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)

# %% [markdown]
# ## Predict Model
#
# This function predicts Label using a trained model. When data is None, it predicts label on the holdout set.
#
# note: so far, our best model is the stacker model with the highest CV R2. :)

# %%
holdout_pred = exp1.predict_model(stacker)
# Out:
# <style type="text/css">
# </style>
# <table id="T_55b26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55b26_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_55b26_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_55b26_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_55b26_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_55b26_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_55b26_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_55b26_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55b26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55b26_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_55b26_row0_col1" class="data row0 col1" >40.6716</td>
#       <td id="T_55b26_row0_col2" class="data row0 col2" >3189.9772</td>
#       <td id="T_55b26_row0_col3" class="data row0 col3" >56.4799</td>
#       <td id="T_55b26_row0_col4" class="data row0 col4" >0.9065</td>
#       <td id="T_55b26_row0_col5" class="data row0 col5" >0.5487</td>
#       <td id="T_55b26_row0_col6" class="data row0 col6" >0.6132</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Finalize Model
#
# This function trains a given estimator on the entire dataset including the holdout set.
#
# Model finalization is the last step in the experiment. A normal machine learning workflow in PyCaret starts with setup(), followed by comparing all models using compare_models() and shortlisting a few candidate models (based on the metric of interest) to perform several modeling techniques such as hyperparameter tuning, ensembling, stacking etc. This workflow will eventually lead you to the best model for use in making predictions on new and unseen data. The finalize_model() function fits the model onto the complete dataset including the test/hold-out sample (30% in this case). The purpose of this function is to train the model on the complete dataset before it is deployed in production.

# %%
final_stacker = exp1.finalize_model(stacker)

# %%
final_stacker
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('placeholder', None),
#                 ('actual_estimator',
#                  StackingRegressor(cv=5,
#                                    estimators=[('CatBoost Regressor',
#                                                 CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                                                ('Light Gradient Boosting '
#                                                 'Machine',
#                                                 LGBMRegressor(n_jobs=-1,
#                                                               random_state=555)),
#                                                ('Extreme Gradient Boosting'...
#                                                              interaction_constraints=None,
#                                                              learning_rate=None,
#                                                              max_bin=None,
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=None,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=None,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None, ...))],
#                                    final_estimator=LinearRegression(n_jobs=-1),
#                                    n_jobs=-1))])

# %% [markdown]
# ### Final prediciton on unseen data
#
# The predict_model() function is also used to predict on the unseen dataset. The only difference from section 11 above is that this time we will pass the data_unseen parameter. data_unseen is the variable created at the beginning of the tutorial and contains 10% of the original dataset which was never exposed to PyCaret.

# %%
unseen_predictions = exp1.predict_model(final_stacker, data=data_unseen)
unseen_predictions.tail()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7059f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7059f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7059f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7059f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7059f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7059f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7059f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7059f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7059f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7059f_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_7059f_row0_col1" class="data row0 col1" >32.8933</td>
#       <td id="T_7059f_row0_col2" class="data row0 col2" >2015.1268</td>
#       <td id="T_7059f_row0_col3" class="data row0 col3" >44.8902</td>
#       <td id="T_7059f_row0_col4" class="data row0 col4" >0.9281</td>
#       <td id="T_7059f_row0_col5" class="data row0 col5" >0.5088</td>
#       <td id="T_7059f_row0_col6" class="data row0 col6" >0.7269</td>
#     </tr>
#   </tbody>
# </table>
#     instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 95    14959   9/20/2012       3   1     9  11        0        4           1
# 96     9419    2/2/2012       1   1     2   8        0        4           1
# 97    15874  10/28/2012       4   1    10  14        0        0           0
# 98    15938   11/1/2012       4   1    11  18        0        4           1
# 99    17174  12/23/2012       1   1    12   8        0        0           0
#
#     weathersit  temp   atemp   hum  windspeed  cnt  prediction_label
# 95           1  0.62  0.6212  0.43     0.0000  243        337.336779
# 96           3  0.40  0.4091  0.87     0.0000  445        332.770565
# 97           2  0.50  0.4848  0.59     0.4478  402        428.502890
# 98           2  0.40  0.4091  0.50     0.1642  678        569.470162
# 99           1  0.14  0.1667  0.69     0.1045   48         48.458711

# %% [markdown]
# ## Save Model
#
# This function saves the transformation pipeline and trained model object into the current working directory as a pickle file for later use.

# %%
exp1.save_model(final_stacker, 'my_pycaret_regression')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('placeholder', None),
#                  ('actual_estimator',
#                   StackingRegressor(cv=5,
#                                     estimators=[('CatBoost Regressor',
#                                                  CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                                                 ('Light Gradient Boosting '
#                                                  'Machine',
#                                                  LGBMRegressor(n_jobs=-1,
#                                                                random_state=555)),
#                                                 ('Extreme Gradient Boosting'...
#                                                               interaction_constraints=None,
#                                                               learning_rate=None,
#                                                               max_bin=None,
#                                                               max_cat_threshold=None,
#                                                               max_cat_to_onehot=None,
#                                                               max_delta_step=None,
#                                                               max_depth=None,
#                                                               max_leaves=None,
#                                                               min_child_weight=None,
#                                                               missing=nan,
#                                                               monotone_constraints=None,
#                                                               multi_strategy=None,
#                                                               n_estimators=None,
#                                                               n_jobs=-1,
#                                                               num_parallel_tree=None, ...))],
#                                     final_estimator=LinearRegression(n_jobs=-1),
#                                     n_jobs=-1))]),
#  'my_pycaret_regression.pkl')

# %% [markdown]
# ## Load model
#
# This function loads a previously saved pipeline.

# %%
my_winning_regressor = load_model('my_pycaret_regression')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
my_winning_regressor
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('placeholder', None),
#                 ('actual_estimator',
#                  StackingRegressor(cv=5,
#                                    estimators=[('CatBoost Regressor',
#                                                 CatBoostRegressor(border_count=254, loss_function='RMSE', random_state=555, task_type='CPU', verbose=False)),
#                                                ('Light Gradient Boosting '
#                                                 'Machine',
#                                                 LGBMRegressor(n_jobs=-1,
#                                                               random_state=555)),
#                                                ('Extreme Gradient Boosting'...
#                                                              interaction_constraints=None,
#                                                              learning_rate=None,
#                                                              max_bin=None,
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=None,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=None,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None, ...))],
#                                    final_estimator=LinearRegression(n_jobs=-1),
#                                    n_jobs=-1))])

# %% [markdown]
# ## Deploy Model
#
# This function deploys the transformation pipeline and trained model on cloud.
#
# https://py-caret.readthedocs.io/en/latest/api/generated/pycaret.regression.deploy_model.html
